# %%
import pandas as pd
import numpy as np
import re

# %%
pd.set_option("display.max_columns", None)

# %%
df = pd.read_csv('mysmartprice_mobile_dataset.csv')

# %%
df.sample(5)
# Out:
#           brand                model release_date     price  avg_rating  \
# 1300       Asus  Rog phone 8 pro 1tb   2024-01-29  119999.0         NaN
# 4058      Forme              Mini 11   2021-07-20    1149.0         4.0
# 2719     I Kall            Kall k200   2020-09-30    3599.0         3.4
# 4983     I Kall             Kall z14   2022-08-09    6789.0         3.3
# 2038  Panasonic                 P100   2018-02-07    5299.0         3.8
#
#       total_ratings rear_camera front_camera display_size(inch)  \
# 1300            NaN   50+13+32           32                6.78
# 4058            1.0        0.3           NaN                2.8
# 2719        17900.0          5            2                 5.5
# 4983          413.0         20           13                6.82
# 2038         2321.0          8            5                 5.0
#
#      refresh_rate(Hz)     display_type  battery_size(mAh)  charging_speed(W)  \
# 1300              165  Flexible AMOLED             5500.0               30.0
# 4058              NaN              TFT             1800.0                NaN
# 2719              NaN          IPS LCD             2500.0                NaN
# 4983              NaN          IPS LCD             5000.0                NaN
# 2038              NaN          IPS LCD             2200.0                NaN
#
#       os_type os_version   5g  nfc fingerprint  \
# 1300  Android        v14  yes  yes         yes
# 4058      NaN        NaN   no   no          no
# 2719  Android       v6.0   no   no          no
# 4983  Android        v10   no   no         yes
# 2038  Android       v7.0   no   no         yes
#
#                                             expert_view  ram(gb)  storage(gb)  \
# 1300                                                NaN     24.0     0.000977
# 4058                                                NaN      NaN          NaN
# 2719                                                NaN      2.0    16.000000
# 4983  The I Kall Z14 is a regular option in this pri...      4.0    64.000000
# 2038                                                NaN      1.0    16.000000
#
#        cpu_brand          cpu_model
# 1300  Snapdragon  8 Gen 3 Octa core
# 4058         NaN                nan
# 2719         NaN          Quad core
# 4983         NaN          Quad core
# 2038    MediaTek          Quad core

# %% [markdown]
# #####
# - drop col:['mobile_name','battery_and_charging_speed','operating_system','5G|NFC|Fingerprint','ram_and_storage']
# - col:price -> price(INR)
# - col:front_camera -> front_camera(MP)

# %%
df.drop(columns=['Unnamed: 0'],inplace=True)

# %%
df.info(show_counts=True)
# Out:
# <class 'pandas.core.frame.DataFrame'>
# RangeIndex: 5263 entries, 0 to 5262
# Data columns (total 23 columns):
#  #   Column              Non-Null Count  Dtype
# ---  ------              --------------  -----
#  0   brand               5263 non-null   object
#  1   model               5262 non-null   object
#  2   release_date        5215 non-null   datetime64[ns]
#  3   price               5251 non-null   float64
#  4   avg_rating          4700 non-null   float64
#  5   total_ratings       4700 non-null   float64
#  6   rear_camera         5110 non-null   object
#  7   front_camera        3494 non-null   object
#  8   display_size(inch)  5260 non-null   object
#  9   refresh_rate(Hz)    1526 non-null   object
#  10  display_type        4809 non-null   object
#  11  battery_size(mAh)   5236 non-null   float64
#  12  charging_speed(W)   1871 non-null   float64
#  13  os_type             3501 non-null   object
#  14  os_version          3464 non-null   object
#  15  5g                  5263 non-null   object
#  16  nfc                 5263 non-null   object
#  17  fingerprint         5263 non-null   object
#  18  expert_view         1421 non-null   object
#  19  ram(gb)             3899 non-null   float64
#  20  storage(gb)         3917 non-null   float64
#  21  cpu_brand           2996 non-null   object
#  22  cpu_model           5263 non-null   object
# dtypes: datetime64[ns](1), float64(7), object(15)
# memory usage: 945.8+ KB

# %%
#extract brand name seperately
df.insert(0,'brand',df['mobile_name'].str.split(' ', n=1).str[0].str.capitalize())

# %%
#handle brand "I Kall"
df['brand'].replace('I', 'I Kall',inplace=True)
# Out:
# /var/folders/s_/8psmrzpd1ljgqhthwdx4fv000000gn/T/ipykernel_28851/4139014912.py:2: FutureWarning: A value is trying to be set on a copy of a DataFrame or Series through chained assignment using an inplace method.
# The behavior will change in pandas 3.0. This inplace method will never work because the intermediate object on which we are setting values always behaves as a copy.
#
# For example, when doing 'df[col].method(value, inplace=True)', try using 'df.method({col: value}, inplace=True)' or df[col] = df[col].method(value) instead, to perform the operation inplace on the original object.
#
#
#   df['brand'].replace('I', 'I Kall',inplace=True)

# %%
#extract model seperately
df.insert(1,'model',df['mobile_name'].str.split(' ', n=1).str[1].str.capitalize())

# %%
#convert release_date to datetime
df['release_date'] = pd.to_datetime(df['release_date'].str.split(':').str[1])

# %%
#convert ratings column to float
def convert_ratings(value):
    if pd.isna(value):  # Handle NaN values
        return np.nan
    
    value = value.split(' ')[0]

    if 'K' in value:
        return (float(value.replace(',','').replace('K',''))*1000)
    elif 'L' in value:
        return (float(value.replace(',','').replace('L',''))*100000)
    else:
        return (float(value.replace(',','')))

df['total_ratings'] = df['total_ratings'].astype(str).apply(convert_ratings)

# %%
#change price to float
df['price'] = df['price'].str.replace('₹','').str.replace(',','').astype(float)

# %%
#clean col : front camera
df['front_camera'] = df['front_camera'].str.replace('MP Front Camera','')

# %%
#clean col : rear camera
df['rear_camera'] = df['rear_camera'].str.replace('MP Rear Camera','')

# %%
#create new col: battery_size(mAh)
df.insert(12,'battery_size(mAh)',df['battery_and_charging_speed'].str.split(' ',n=1).str[0].astype(float))

# %%
#create new col : charging_speed(W)
df.insert(13,'charging_speed(W)',df['battery_and_charging_speed'].str.split('|',n=1).str[1].str.strip().str.split('W').str[0].astype(float))

# %%
#operating system -> create new cols:os_type,os_version
df['operating_system'] = df['operating_system'].str.replace(' OS','',)
df.insert(15,'os_type',df['operating_system'].str.split(' ',n=1).str[0])
df.insert(16,'os_version',df['operating_system'].str.split(' ',n=1).str[1])

# %%
#add cols : 5g,nfc,fingerprint
df.insert(18,'5g',df['5G|NFC|Fingerprint'].astype(str).apply(lambda x: 'yes' if '5G' in x else 'no'))
df.insert(19, 'nfc', df['5G|NFC|Fingerprint'].astype(str).apply(lambda x: 'yes' if 'NFC' in x else 'no'))
df.insert(20, 'fingerprint', df['5G|NFC|Fingerprint'].astype(str).apply(lambda x: 'yes' if 'Fingerprint' in x else 'no'))

# %%
import numpy as np
import pandas as pd

def extract_size(value):
    """Extracts numeric size and converts MB to GB if needed."""
    parts = value.strip().split(' ')  # Extract number and unit
    num = float(parts[0])  # Convert to float
    return num if 'GB' in value else num / 1024  # Convert MB to GB

def ram_and_storage(value):
    """Extracts RAM and Storage values separately in GB."""
    if pd.isna(value):  # Handle NaN values
        return np.nan, np.nan

    ram, storage = np.nan, np.nan  # Default values
    parts = value.split('|')  # Split RAM and Storage

    for part in parts:
        part = part.strip()
        if 'RAM' in part:
            ram = extract_size(part)
        elif 'Storage' in part:
            storage = extract_size(part)

    return ram, storage

# Apply function and create new columns
df[['ram(gb)', 'storage(gb)']] = df['ram_and_storage'].astype(str).apply(lambda x: pd.Series(ram_and_storage(x)))

# %%
#add col:display_size(inch)
df.insert(10,'display_size(inch)',df['display'].str.split('″').str[0])

# %%
#add col :refresh_rate(Hz)
df.insert(11,'refresh_rate(Hz)',df['display'].astype(str).apply(lambda x : (re.search(r'(\d+)(\s*)Hz',x).group(1)) if re.search(r'(\d+)(\s*)Hz',x) else np.nan))

# %%
#add col:display_type
display_types = ['TFT', 'TFT LCD', 'TFT LTPS' ,'TFD', 
 'IPS LCD', 'IPS LED', 'IPS Plus LCD',
 'HD IGZO LCD', 'S-LCD 5', 'LCD','PLS LCD','S-LCD' ,'S-LCD 3','S-LCD 2', 'AHVA LCD', 'LTPS LCD'
 'AMOLED' , 'Super AMOLED', 'Optic AMOLED', 'Dynamic AMOLED', 'Fluid AMOLED', 'Flexible AMOLED', 'Flexi-fluid AMOLED', 'Super AMOLED Plus', 'LTPO AMOLED', 'LTPS AMOLED', 'Super Fluid AMOLED',
 'P-OLED','OLED', 'LTPO OLED', 
 'Super Retina XDR','ProXDR LTPO']

def extract_display_type(text):

    for display in display_types:
        if re.search(rf'\b{re.escape(display)}\b', text, re.IGNORECASE):
            return display
    return np.nan  # Return None if no match found

df.insert(12,'display_type',pd.Series(df['display'].astype(str).apply(extract_display_type)))

# %%
brands = ['Snapdragon', 'Samsung', 'MediaTek', 'Apple', 'Unisoc', 'Google', 'HiSilicon', 'Spreadtrum', 'ST-Ericsson', 'Marvell', 'Huawei', 'Broadcom', 'Intel', 'Nvidia']

def cpu_brand(value):
    
    #If nan value
    if value == np.nan:
        return np.nan , np.nan
    
    for brand in brands:
        if brand in value:
            print(value)
            if len(value.split())>1:
                return value.split(' ')[0] , ' '.join(value.split(' ')[1:])
            else:
                return np.nan,value
    
    return np.nan,value


df[['cpu_brand','cpu_model']] = df['cpu'].astype(str).apply(lambda x: pd.Series(cpu_brand(x)))
# Out:
# Snapdragon 8 Elite Octa core
# Snapdragon 8 Elite Octa core
# Snapdragon 8 Elite Octa core
# Samsung Exynos 1380 Octa core
# Snapdragon 7s Gen 2 Octa core
# Snapdragon 6s Gen 3 Octa core
# Snapdragon 7 Gen 3 Octa core
# Snapdragon 8 Gen 3 Octa core
# Snapdragon 7 Gen 3 Octa core
# Snapdragon 7s Gen 3 Octa core
# Snapdragon 8 Gen 3 Octa core
# Samsung Exynos 1380 Octa core
# Snapdragon 8 Elite Octa core
# Snapdragon 7 Gen 3 Octa core
# Snapdragon 7 Plus Gen 3 Octa core
# MediaTek Dimensity 8400 Ultra Octa core
# Snapdragon 7 Gen 3 Octa core
# MediaTek Dimensity 9400 Octa core
# MediaTek Dimensity 7025 Ultra Octa core
# MediaTek Dimensity 7300 Octa core
# MediaTek Dimensity 8350 Octa core
# MediaTek Dimensity 7300 Octa core
# MediaTek Dimensity 7300 Ultra Octa core
# Snapdragon 7s Gen 2 Octa core
# MediaTek Dimensity 6300 Octa core
# MediaTek Dimensity 7300 Octa core
# Snapdragon 7 Plus Gen 3 Octa core
# Snapdragon 7 Gen 3 Octa core
# Snapdragon 8 Elite Octa core
# Snapdragon 6 Gen 1 Octa core
# MediaTek Dimensity 7300 Ultra Octa core
# Samsung Exynos 1480 Octa core
# MediaTek Dimensity 7300 Octa core
# MediaTek Dimensity 6300 Octa core
# Snapdragon 8 Gen 2 Octa core
# MediaTek Dimensity 7050 Octa core
# Snapdragon 6s Gen 3 Octa core
# MediaTek Dimensity 9200 Plus Octa core
# MediaTek Dimensity 7025 Ultra Octa core
# Samsung Exynos 2200 Octa core
# MediaTek Dimensity 8350 Octa core
# Snapdragon 8s Gen 3 Octa core
# Snapdragon 4 Gen 2 Octa core
# Samsung Exynos 2400 Deca Core
# Apple A18 Pro Hexa Core
# Snapdragon 8 Gen 2 Octa core
# MediaTek Dimensity 7200 Octa core
# MediaTek Dimensity 7300 Energy Octa core
# Samsung Exynos 2400e Deca Core
# MediaTek Dimensity 6080 Octa core
# MediaTek Dimensity 9200 Plus Octa core
# Snapdragon 6 Gen 1 Octa core
# Snapdragon 4 Gen 2 Octa core
# Snapdragon 7 Gen 3 Octa core
# MediaTek Dimensity 7300 Energy Octa core
# Snapdragon 8 Gen 2 Octa core
# MediaTek Dimensity 6300 Octa core
# Snapdragon 7 Gen 3 Octa core
# Snapdragon 7 Gen 1 Octa core
# MediaTek Dimensity 7025 Octa core
# MediaTek Dimensity 7200 Pro Octa core
# Snapdragon 695 Octa core
# Snapdragon 7s Gen 2 Octa core
# Snapdragon 4 Gen 2 Octa core
# MediaTek Dimensity 7200 Ultra Octa core
# Snapdragon 8 Gen 2 Octa core
# MediaTek Dimensity 9400 Octa core
# Snapdragon 7 Gen 1 Accelerated Edition Octa core
# Snapdragon 8 Elite Octa core
# Snapdragon 7s Gen 2 Octa core
# Apple A18 Hexa Core
# MediaTek Dimensity 7050 Octa core
# Apple A16 Bionic Hexa Core
# MediaTek Dimensity 8200 Ultimate Octa core
# MediaTek Dimensity 6100 Plus Octa core
# MediaTek Dimensity 6080 Octa core
# MediaTek Dimensity 7020 Octa core
# MediaTek Dimensity 7050 Octa core
# Samsung Exynos 2400 Deca Core
# MediaTek Dimensity 9400 Octa core
# Snapdragon 8s Gen 3 Octa core
# Snapdragon 8s Gen 3 Octa core
# Snapdragon 8s Gen 3 Octa core
# MediaTek Dimensity 7050 Octa core
# Snapdragon 8 Gen 1 Octa core
# Snapdragon 4s Gen 2 Octa core
# MediaTek Dimensity 6100 Plus Octa core
# MediaTek Dimensity 8300 Ultra Octa core
# MediaTek Dimensity 7200 Octa core
# Snapdragon 8 Gen 3 Octa core
# MediaTek Dimensity 7300 Energy Octa core
# Apple A15 Bionic Hexa Core
# MediaTek Dimensity 6300 Octa core
# Snapdragon 6 Gen 1 Octa core
# Unisoc Octa core
# Snapdragon 7s Gen 2 Octa core
# MediaTek Dimensity 7350 Pro Octa core
# MediaTek Dimensity 8200 Octa core
# Google Tensor G3 Nona Core
# Snapdragon 8 Gen 3 Octa core
# Snapdragon 7s Gen 2 Octa core
# Snapdragon 7s Gen 2 Octa core
# Snapdragon 695 Octa core
# MediaTek Dimensity 7300 Energy Octa core
# Snapdragon 6 Gen 1 Octa core
# MediaTek Helio G81 Extreme Octa core
# MediaTek Helio G85 Octa core
# Snapdragon 8s Gen 3 Octa core
# Snapdragon 695 Octa core
# Apple A18 Pro Hexa Core
# Google Tensor G4 Octa core
# MediaTek Dimensity 7300 Energy Octa core
# MediaTek Dimensity 6100 Plus Octa core
# Snapdragon 4s Gen 2 Octa core
# Snapdragon 8 Gen 3 Octa core
# Apple A16 Bionic Hexa Core
# MediaTek Dimensity 6300 Octa core
# MediaTek Dimensity 6300 Octa core
# Unisoc Tru-Octa Core
# MediaTek Dimensity 6100 Plus Octa core
# Samsung Exynos 2100 Octa core
# MediaTek Dimensity 7050 Octa core
# MediaTek Dimensity 6300 Octa core
# Snapdragon 8 Plus Gen 1 Octa core
# Snapdragon 7s Gen 2 Octa core
# Google Tensor G2 Octa core
# Snapdragon 782G Octa core
# MediaTek Dimensity 6300 Octa core
# MediaTek Dimensity 6100 Plus Octa core
# Samsung Exynos 1380 Octa core
# MediaTek Dimensity 6300 Octa core
# Snapdragon 8 Plus Gen 1 Octa core
# MediaTek Dimensity 7300 Energy Octa core
# MediaTek Dimensity 9000 Octa core
# MediaTek Dimensity 9300 Octa core
# MediaTek Dimensity 7300X Octa core
# Snapdragon 778G Octa core
# MediaTek Dimensity 8200 Ultimate Octa core
# Snapdragon 4 Gen 1 Octa core
# Snapdragon 8 Elite Octa core
# MediaTek Dimensity 9400 Octa core
# Snapdragon 8 Gen 3 Octa core
# MediaTek Dimensity 6300 Octa core
# Apple A15 Bionic Hexa Core
# Snapdragon 6 Gen 1 Octa core
# MediaTek Helio G85 Octa core
# MediaTek Dimensity 6100 Plus Octa core
# Samsung Exynos 1380 Octa core
# MediaTek Dimensity 6300 Octa core
# MediaTek Dimensity 7050 Octa core
# Samsung Exynos 1380 Octa core
# MediaTek Helio G36 Octa core
# Samsung Exynos 1330 Octa core
# Snapdragon 7s Gen 3 Octa core
# Snapdragon 8 Gen 1 Octa core
# MediaTek Helio G85 Octa core
# MediaTek Dimensity 6300 Octa core
# MediaTek Dimensity 6300 Octa core
# Snapdragon 778G Plus Octa core
# MediaTek Dimensity 6300 Octa core
# Google Tensor G3 Nona Core
# Snapdragon 7 Gen 1 Octa core
# Snapdragon 7s Gen 2 Octa core
# Apple A18 Hexa Core
# MediaTek Dimensity 9000 Octa core
# Apple A17 Pro Hexa Core
# Snapdragon 6 Gen 1 Octa core
# MediaTek Dimensity 7020 Octa core
# Snapdragon 6s Gen 3 Octa core
# Snapdragon 7s Gen 3 Octa core
# Google Tensor G4 Octa core
# Snapdragon 7 Plus Gen 2 Octa core
# Unisoc Single core
# MediaTek Dimensity 8200 Octa core
# Apple A13 Bionic Hexa Core
# Snapdragon 4 Gen 2 Octa core
# Snapdragon 865 Octa core
# MediaTek Dimensity 9300 Octa core
# Snapdragon 8 Gen 1 Octa core
# Snapdragon 4 Gen 2 Octa core
# Apple A14 Bionic Hexa Core
# MediaTek Dimensity 7025 Octa core
# MediaTek Dimensity 7200 Octa core
# Snapdragon 4 Gen 2 Octa core
# MediaTek Dimensity 6300 Octa core
# Snapdragon 8 Gen 1 Octa core
# MediaTek Dimensity 7200 Octa core
# MediaTek Dimensity 6300 Octa core
# MediaTek Dimensity 7020 Octa core
# Snapdragon 8 Gen 3 Octa core
# MediaTek Dimensity 9000 Octa core
# Google Tensor G2 Octa core
# Snapdragon 888 Octa core
# Google Tensor Octa core
# Snapdragon 6s Gen 3 Octa core
# Unisoc Octa core
# Snapdragon 778G Octa core
# Snapdragon 695 Octa core
# MediaTek Dimensity 7050 Octa core
# Snapdragon 4 Gen 1 Octa core
# Snapdragon 8 Gen 2 Octa core
# MediaTek Dimensity 6300 Octa core
# Samsung Exynos 9 Octa Octa core
# MediaTek Dimensity 6300 Octa core
# Samsung Exynos 1380 Octa core
# Snapdragon 8 Elite Octa core
# Snapdragon 7 Gen 3 Octa core
# MediaTek Dimensity 6080 Octa core
# Google Tensor G2 Octa core
# MediaTek Dimensity 7025 Octa core
# Snapdragon 8 Gen 1 Octa core
# Apple A17 Pro Hexa Core
# MediaTek Dimensity 6100 Plus Octa core
# Samsung Exynos 2100 Octa core
# MediaTek Dimensity 1080 Octa core
# MediaTek Dimensity 6100 Plus Octa core
# MediaTek Dimensity 8020 Octa core
# MediaTek Dimensity 7030 Octa core
# Samsung Exynos Octa core
# MediaTek Dimensity 6080 Octa core
# MediaTek Dimensity 6300 Octa core
# Snapdragon 7 Gen 3 Octa core
# Snapdragon 4 Gen 2 Octa core
# MediaTek Dimensity 6300 Octa core
# Snapdragon 8 Elite Octa core
# Snapdragon 4 Gen 2 Octa core
# Unisoc Octa core
# MediaTek Helio G85 Octa core
# MediaTek Dimensity 7200 Octa core
# MediaTek Dimensity 7050 Octa core
# Samsung Exynos Octa core
# Snapdragon 870 Octa core
# MediaTek Dimensity 8200 Octa core
# Snapdragon 8 Plus Gen 1 Octa core
# Snapdragon 6 Gen 1 Octa core
# MediaTek Dimensity 8200 Octa core
# Snapdragon 8 Gen 2 Octa core
# Snapdragon 480 Plus Octa core
# Samsung Exynos 9 Octa Octa core
# MediaTek Dimensity 7300 Octa core
# MediaTek Dimensity 7050 Octa core
# MediaTek Dimensity 7050 Octa core
# Snapdragon 7 Plus Gen 3 Octa core
# Snapdragon 8 Gen 3 Octa core
# MediaTek Dimensity 1080 Octa core
# MediaTek Helio G85 Octa core
# Apple A14 Bionic Hexa Core
# MediaTek Dimensity 6300 Octa core
# Unisoc Tru-Octa Core
# Snapdragon 7 Plus Gen 3 Octa core
# Snapdragon 8 Elite Octa core
# Unisoc Octa core
# MediaTek Dimensity 6100 Plus Octa core
# Snapdragon 8 Elite Octa core
# MediaTek Dimensity 7050 Octa core
# Snapdragon 860 Octa core
# Snapdragon 7 Gen 1 Octa core
# Snapdragon 7 Gen 3 Octa core
# MediaTek Dimensity 6080 Octa core
# Snapdragon 778G Octa core
# MediaTek Helio G50 Octa core
# Samsung Exynos Octa core
# Apple A16 Bionic Hexa Core
# Snapdragon 680 Octa core
# MediaTek Dimensity 6020 Octa core
# Snapdragon 6 Gen 1 Octa core
# Snapdragon 4 Gen 2 Octa core
# Samsung Exynos 2100 Octa core
# Snapdragon 8s Gen 3 Octa core
# Unisoc Octa core
# MediaTek Dimensity 8050 Octa core
# MediaTek Dimensity 8100 Max Octa core
# Snapdragon 7 Gen 1 Octa core
# Samsung Exynos 9 Octa Octa core
# MediaTek Dimensity 6300 Octa core
# Snapdragon 865 Octa core
# MediaTek Dimensity 8400 Ultra Octa core
# Snapdragon 7 Gen 3 Octa core
# Samsung Exynos 9 Octa Octa core
# MediaTek Helio G85 Octa core
# MediaTek Dimensity 7020 Octa core
# MediaTek Dimensity 7025 Ultra Octa core
# MediaTek Dimensity 1300 Octa core
# Snapdragon 888 Octa core
# Unisoc Tru-Octa Core
# Snapdragon 8 Gen 2 Octa core
# Snapdragon 460 Octa core
# Snapdragon 680 Octa core
# MediaTek Dimensity 6100 Plus Octa core
# Snapdragon 4s Gen 2 Octa core
# MediaTek Dimensity 700 Octa core
# Snapdragon 7 Plus Gen 2 Octa core
# MediaTek Dimensity 8100 Max Octa core
# Snapdragon 7s Gen 3 Octa core
# Snapdragon 695 Octa core
# Snapdragon 7 Gen 1 Accelerated Edition Octa core
# Snapdragon 765G Octa core
# Unisoc Octa core
# Apple A15 Bionic Hexa Core
# Unisoc Octa core
# MediaTek Helio G85 Octa core
# Snapdragon 8 Gen 1 Octa core
# Apple A15 Bionic Hexa Core
# Google Tensor G3 Nona Core
# MediaTek Dimensity 6300 Octa core
# Unisoc
# MediaTek Dimensity 6300 Octa core
# MediaTek Dimensity 1200 Octa core
# MediaTek Dimensity 8200 Ultimate Octa core
# Snapdragon 8 Gen 3 Octa core
# Snapdragon 695 Octa core
# MediaTek Dimensity 6020 Octa core
# Snapdragon 8s Gen 3 Octa core
# Snapdragon 6 Gen 1 Octa core
# MediaTek Helio G85 Octa core
# MediaTek Dimensity 900 Octa core
# Snapdragon 8 Gen 2 Octa core
# Samsung Exynos 1330 Octa core
# MediaTek Dimensity 900 Octa core
# Apple A16 Bionic Hexa Core
# MediaTek Dimensity 1300 Octa core
# Snapdragon 8 Gen 2 Octa core
# MediaTek Dimensity 8020 Octa core
# MediaTek Dimensity 6300 Octa core
# Snapdragon 695 Octa core
# Snapdragon 730G Octa core
# Snapdragon 810 Octa core
# Snapdragon 695 Octa core
# Snapdragon 8 Gen 3 Octa core
# Snapdragon 870 Octa core
# MediaTek Helio G88 Octa core
# Snapdragon 888 Octa core
# Samsung Exynos 1480 Octa core
# MediaTek Dimensity 6020 Octa core
# Snapdragon 8 Gen 3 Octa core
# MediaTek Dimensity 1200 Octa core
# MediaTek Dimensity 8020 Octa core
# Samsung Exynos 9 Octa Octa core
# Samsung Exynos 1380 Octa core
# MediaTek Dimensity 7300 Energy Octa core
# MediaTek Dimensity 7300 Octa core
# MediaTek Helio G88 Octa core
# MediaTek Helio G36 Octa core
# Apple A14 Bionic Hexa Core
# Snapdragon 8 Plus Gen 1 Octa core
# MediaTek Dimensity 6100 Plus Octa core
# Snapdragon 695 Octa core
# MediaTek Dimensity 6300 Octa core
# MediaTek Dimensity 9000 Plus Octa core
# MediaTek Dimensity 8200 Octa core
# MediaTek Dimensity 6080 Octa core
# MediaTek Dimensity 6100 Plus Octa core
# MediaTek Dimensity 8350 Octa core
# Snapdragon 7 Plus Gen 3 Octa core
# Snapdragon 888 Octa core
# Unisoc
# Snapdragon 8 Plus Gen 1 Octa core
# MediaTek Dimensity 1080 Octa core
# MediaTek Dimensity 1300 Octa core
# Snapdragon 7s Gen 2 Octa core
# MediaTek Dimensity 900 Octa core
# MediaTek Helio G91 Octa core
# MediaTek Dimensity 7050 Octa core
# MediaTek Dimensity 6100 Plus Octa core
# MediaTek Dimensity 7350 Pro Octa core
# Snapdragon 4 Gen 2 Octa core
# Snapdragon 460 Octa core
# Samsung Exynos 1330 Octa core
# Snapdragon 8 Gen 3 Octa core
# MediaTek Dimensity 9200 Octa core
# Snapdragon 888 Octa core
# Snapdragon 8 Gen 2 Octa core
# MediaTek Dimensity 8300 Ultra Octa core
# Apple A18 Pro Hexa Core
# Samsung Exynos Octa core
# Snapdragon 8s Gen 3 Octa core
# Apple A13 Bionic Hexa Core
# MediaTek Dimensity 810 Octa core
# MediaTek Dimensity 900 Octa core
# Snapdragon 695 Octa core
# MediaTek Dimensity 8200 Octa core
# Snapdragon 8 Gen 1 Octa core
# MediaTek Helio G36 Octa core
# MediaTek Dimensity 9200 Octa core
# Snapdragon 6 Gen 1 Octa core
# Snapdragon 8 Elite Octa core
# Snapdragon 750G Octa core
# MediaTek Dimensity 7300 Energy Octa core
# Apple A15 Bionic Hexa Core
# Google Tensor G4 Octa core
# Snapdragon 480 Plus Octa core
# MediaTek Dimensity 6300 Octa core
# Snapdragon 7 Gen 3 Octa core
# MediaTek Dimensity 7300 Octa core
# Snapdragon 865 Octa core
# Unisoc Octa core
# Snapdragon 8 Gen 3 Octa core
# MediaTek Dimensity 6080 Octa core
# MediaTek Dimensity 9200 Plus Octa core
# Snapdragon 7 Gen 3 Octa core
# Samsung Exynos 7 Octa Octa core
# Snapdragon 7s Gen 2 Octa core
# Snapdragon 7 Gen 1 Octa core
# MediaTek Helio G50 Tru-Octa Core
# Snapdragon 480 Plus Octa core
# Snapdragon 7 Gen 3 Octa core
# MediaTek Dimensity 1200 Octa core
# MediaTek Dimensity 8100 Octa core
# MediaTek Dimensity 1080 Octa core
# MediaTek Dimensity 7025 Ultra Octa core
# Samsung Exynos 9 Octa Octa core
# HiSilicon Kirin Octa core
# Snapdragon 7s Gen 3 Octa core
# MediaTek Dimensity 6300 Octa core
# Snapdragon 8s Gen 3 Octa core
# MediaTek Helio G90T Octa core
# Snapdragon 6s 4G Gen 1 Octa core
# Snapdragon 888 Octa core
# MediaTek Dimensity 900 Octa core
# Snapdragon 695 Octa core
# Snapdragon 8 Gen 3 Octa core
# Samsung Exynos 1480 Octa core
# Snapdragon 870 Octa core
# Snapdragon 870 Octa core
# MediaTek Dimensity 6300 Octa core
# MediaTek Helio G99 Octa core
# MediaTek Dimensity 9000 Octa core
# MediaTek Dimensity 7300 Ultra Octa core
# Snapdragon 665 Octa core
# Snapdragon 732G Octa core
# Snapdragon 750G Octa core
# HiSilicon Kirin Octa core
# MediaTek Dimensity 7200 Pro Octa core
# Snapdragon 8 Elite Octa core
# Samsung Exynos 9 Octa Octa core
# Snapdragon 8 Plus Gen 1 Octa core
# MediaTek Dimensity 7300 Ultra Octa core
# Apple A12 Bionic Hexa Core
# Snapdragon 695 Octa core
# Snapdragon 888 Plus Octa core
# Unisoc Octa core
# Snapdragon 888 Plus Octa core
# Snapdragon 8 Gen 1 Octa core
# MediaTek Dimensity 8050 Octa core
# Snapdragon 695 Octa core
# Snapdragon 8 Elite Octa core
# Snapdragon 7 Gen 1 Octa core
# Snapdragon 695 Octa core
# Snapdragon 695 Octa core
# MediaTek Dimensity 7300X Octa core
# MediaTek Dimensity 7050 Octa core
# Snapdragon 8 Gen 2 Octa core
# Snapdragon 678 Octa core
# Snapdragon 720G Octa core
# MediaTek Dimensity 800U Octa core
# MediaTek Helio G88 Octa core
# Samsung Exynos 2100 Octa core
# MediaTek Dimensity 1000 Plus Octa core
# MediaTek Dimensity 6100 Plus Octa core
# MediaTek Dimensity 7025 Octa core
# Apple A14 Bionic Hexa Core
# MediaTek Helio G85 Octa core
# Snapdragon 730G Octa core
# Snapdragon 865 Octa core
# MediaTek Dimensity 8100 Octa core
# MediaTek Dimensity 8050 Octa core
# MediaTek Helio P95 Octa core
# Snapdragon 7s Gen 2 Octa core
# MediaTek Dimensity 8350 Octa core
# Snapdragon 855 Plus Octa core
# Snapdragon 7 Plus Gen 3 Octa core
# Snapdragon 8 Gen 2 Octa core
# MediaTek Dimensity 9400 Octa core
# Snapdragon 855 Octa core
# MediaTek Dimensity 7020 Octa core
# MediaTek Helio P35 Tru-Octa Core
# MediaTek Dimensity 7050 Octa core
# Snapdragon 7s Gen 2 Octa core
# Snapdragon 865 Octa core
# Snapdragon 7s Gen 2 Octa core
# MediaTek Helio G35 Octa core
# Samsung Exynos 2400e Deca Core
# Snapdragon 450 Tru-Octa Core
# Snapdragon 778G Octa core
# Apple A11 Bionic Hexa Core
# Snapdragon 695 Octa core
# MediaTek Dimensity 6100 Plus Octa core
# MediaTek Helio G85 Octa core
# MediaTek Helio G85 Octa core
# Snapdragon 778G Octa core
# Snapdragon 8 Gen 2 Octa core
# Snapdragon 665 Octa core
# MediaTek Helio G95 Octa core
# Snapdragon 778G Octa core
# Apple A15 Bionic Hexa Core
# Samsung Exynos 9 Octa Octa core
# Snapdragon 680 Octa core
# MediaTek Dimensity 6300 Octa core
# MediaTek Helio G96 Octa core
# MediaTek Dimensity 700 Octa core
# Snapdragon 662 Octa core
# MediaTek Dimensity 7050 Octa core
# MediaTek Dimensity 6300 Octa core
# MediaTek Dimensity 920 Octa core
# Snapdragon 680 Octa core
# Apple A15 Bionic Hexa Core
# MediaTek Dimensity 810 Octa core
# MediaTek Dimensity 1200 Octa core
# Snapdragon 7 Gen 1 Octa core
# Apple A12 Bionic Hexa Core
# Snapdragon 7 Gen 3 Octa core
# MediaTek Dimensity 6300 Octa core
# MediaTek Helio P65 Octa core
# Snapdragon 695 Octa core
# MediaTek Dimensity 7200 Ultra Octa core
# Snapdragon 888 Octa core
# MediaTek Dimensity 9200 Plus Octa core
# Samsung Exynos 2200 Octa core
# MediaTek Dimensity 7200 Octa core
# MediaTek Dimensity 9200 Plus Octa core
# Snapdragon 8s Gen 3 Octa core
# Snapdragon 4 Gen 2 Accelerated Edition Octa core
# MediaTek Helio P90 Octa core
# Samsung Exynos 9 Octa Octa core
# MediaTek Dimensity 900 Octa core
# MediaTek Helio P95 Octa core
# Snapdragon 7s Gen 2 Octa core
# MediaTek Helio G80 Octa core
# Snapdragon 680 Octa core
# Samsung Exynos 2400 Deca Core
# Apple A18 Hexa Core
# MediaTek Dimensity 8200 Ultimate Octa core
# MediaTek Helio G95 Octa core
# MediaTek Dimensity 6080 Octa core
# Snapdragon 695 Octa core
# Snapdragon 8 Gen 2 Octa core
# MediaTek Dimensity 8020 Octa core
# Snapdragon 8s Gen 3 Octa core
# MediaTek Dimensity 6300 Octa core
# MediaTek Dimensity 7300 Energy Octa core
# Samsung Exynos 9 Octa Octa core
# MediaTek Dimensity 6100 Plus Octa core
# MediaTek Dimensity 7025 Ultra Octa core
# Snapdragon 778G Octa core
# Apple A18 Pro Hexa Core
# Samsung Exynos 9 Octa Octa core
# Samsung Exynos 9 Octa Octa core
# Snapdragon 778G Octa core
# Unisoc Octa core
# MediaTek Dimensity 6080 Octa core
# Snapdragon 732G Octa core
# MediaTek Dimensity 6100 Plus Octa core
# Snapdragon
# MediaTek Helio G36 Octa core
# Snapdragon 8 Plus Gen 1 Octa core
# Snapdragon 4 Gen 2 Octa core
# Snapdragon 720G Octa core
# Snapdragon 778G Octa core
# MediaTek Dimensity 6100 Plus Octa core
# Snapdragon 680 Octa core
# Snapdragon 8 Gen 2 Octa core
# MediaTek Dimensity 8050 Octa core
# MediaTek Dimensity 9400 Octa core
# Snapdragon 4 Gen 2 Octa core
# MediaTek Dimensity 7200 Ultra Octa core
# MediaTek Helio G96 Octa core
# Snapdragon 855 Octa core
# Apple A13 Bionic Hexa Core
# Samsung Exynos Octa core
# Snapdragon 8 Plus Gen 1 Octa core
# Snapdragon 695 Octa core
# Snapdragon 845 Octa core
# Apple A16 Bionic Hexa Core
# MediaTek Dimensity 6080 Octa core
# Unisoc Octa core
# Snapdragon 7 Gen 1 Octa core
# MediaTek Dimensity 6020 Octa core
# MediaTek Helio G35 Octa core
# MediaTek Helio P70 Octa core
# MediaTek Dimensity 6080 Octa core
# Snapdragon 695 Octa core
# MediaTek Dimensity 6300 Octa core
# Snapdragon 680 Octa core
# Snapdragon 720G Octa core
# Snapdragon 680 Octa core
# Unisoc
# Snapdragon 6 Gen 1 Octa core
# Snapdragon 855 Octa core
# Snapdragon 732G Octa core
# Snapdragon 675 Octa core
# MediaTek Helio G85 Octa core
# MediaTek Helio G95 Octa core
# MediaTek Helio G80 Octa core
# MediaTek Dimensity 6020 Octa core
# MediaTek Dimensity 1200-Max Octa core
# Snapdragon 8 Plus Gen 1 Octa core
# Samsung Exynos Octa core
# Snapdragon 7 Gen 1 Accelerated Edition Octa core
# Snapdragon 845 Octa core
# Snapdragon 720G Octa core
# Snapdragon 695 Octa core
# Snapdragon 7s Gen 2 Octa core
# MediaTek Dimensity 6300 Octa core
# MediaTek Helio P35 Octa core
# Snapdragon 720G Octa core
# Snapdragon 8 Gen 1 Octa core
# MediaTek Dimensity 6100 Plus Octa core
# MediaTek Dimensity 6100 Plus Octa core
# Snapdragon 7s Gen 2 Octa core
# MediaTek Helio G25 Tru-Octa Core
# Unisoc
# Snapdragon 730 Octa core
# MediaTek Helio G95 Octa core
# MediaTek Dimensity 7200 Octa core
# Snapdragon 888 Octa core
# Samsung Exynos 1330 Octa core
# Snapdragon 695 Octa core
# Snapdragon 8 Gen 3 Octa core
# MediaTek Dimensity 6100 Plus Octa core
# MediaTek Dimensity 7200 Pro Octa core
# MediaTek Dimensity 6300 Octa core
# MediaTek Dimensity 7030 Octa core
# Snapdragon 7 Plus Gen 3 Octa core
# MediaTek Dimensity 7050 Octa core
# MediaTek Helio G85 Octa core
# Samsung Exynos 8 Octa Octa core
# MediaTek Dimensity 920 Octa core
# Snapdragon 888 Octa core
# Snapdragon 8 Plus Gen 1 Octa core
# Snapdragon 855 Octa core
# Snapdragon 870 Octa core
# Snapdragon 8 Plus Gen 1 Octa core
# MediaTek Dimensity 7020 Octa core
# MediaTek Dimensity 7300 Energy Octa core
# Google Tensor G4 Octa core
# Samsung Exynos 9 Octa Octa core
# MediaTek Dimensity 700 Octa core
# MediaTek Helio P95 Octa core
# Samsung Exynos 9 Octa Octa core
# Snapdragon 870 Octa core
# MediaTek Dimensity 9000 Plus Octa core
# MediaTek Dimensity 6080 Octa core
# Unisoc Octa core
# MediaTek Dimensity 7300X Octa core
# Snapdragon 865 Octa core
# MediaTek Dimensity 7050 Octa core
# Samsung Exynos 1380 Octa core
# Snapdragon 662 Octa core
# MediaTek Helio G80 Octa core
# Unisoc
# Snapdragon 765G Octa core
# MediaTek Helio P35 Tru-Octa Core
# Snapdragon 765G Octa core
# Snapdragon 870 Octa core
# Snapdragon 845 Octa core
# MediaTek Helio G96 Octa core
# MediaTek Helio G96 Octa core
# Unisoc Octa core
# MediaTek Dimensity 6300 Octa core
# Snapdragon 695 Octa core
# MediaTek Dimensity 6100 Plus Octa core
# Samsung Exynos 9 Octa Octa core
# MediaTek Helio P35 Tru-Octa Core
# MediaTek Dimensity 810 Octa core
# Snapdragon 425 Quad core
# MediaTek Helio P35 Tru-Octa Core
# Snapdragon 8 Gen 2 Octa core
# Snapdragon 680 Octa core
# MediaTek Helio P60 Octa core
# Samsung Exynos 9 Octa Octa core
# Snapdragon 662 Octa core
# Snapdragon 8 Gen 1 Octa core
# MediaTek Dimensity 7300 Octa core
# MediaTek Dimensity 700 Octa core
# Apple A13 Bionic Hexa Core
# MediaTek Dimensity 7020 Octa core
# Google Tensor G3 Nona Core
# Snapdragon 7s Gen 2 Octa core
# MediaTek Dimensity 6300 Octa core
# Snapdragon 680 Octa core
# MediaTek Dimensity 6300 Octa core
# Snapdragon 695 Octa core
# MediaTek Dimensity 700 Octa core
# Samsung Exynos 8 Octa Tru-Octa Core
# Snapdragon 8 Gen 2 Octa core
# Unisoc Octa core
# Apple A12 Bionic Hexa Core
# MediaTek Dimensity 900 Octa core
# Snapdragon 8 Gen 1 Octa core
# Snapdragon 680 Octa core
# MediaTek Helio G70 Octa core
# Samsung Exynos 8 Octa Tru-Octa Core
# Snapdragon 778G Octa core
# Snapdragon 888 Octa core
# MediaTek Helio G88 Octa core
# Snapdragon 888 Octa core
# MediaTek Helio G85 Octa core
# Snapdragon 782G Octa core
# MediaTek Dimensity 6020 Octa core
# Snapdragon 695 Octa core
# MediaTek Helio P70 Octa core
# Samsung Exynos 9 Octa Octa core
# Snapdragon 680 Octa core
# Snapdragon 870 Octa core
# Snapdragon 680 Octa core
# Snapdragon 8 Gen 3 Octa core
# Samsung Exynos 9 Octa Octa core
# Snapdragon 765G Octa core
# Snapdragon 680 Octa core
# Snapdragon 7s Gen 2 Octa core
# MediaTek Dimensity 800U Octa core
# Snapdragon 215 Quad core
# MediaTek Dimensity 810 Octa core
# MediaTek Dimensity 6080 Octa core
# Snapdragon 4 Gen 1 Octa core
# MediaTek Dimensity 700 Octa core
# MediaTek Dimensity 7200 Octa core
# MediaTek Helio P70 Octa core
# Snapdragon 855 Plus Octa core
# Snapdragon 720G Octa core
# MediaTek Quad core
# MediaTek Dimensity 8020 Octa core
# Snapdragon 8 Gen 2 Octa core
# MediaTek Dimensity 7050 Octa core
# Unisoc Octa core
# Snapdragon 625 Tru-Octa Core
# MediaTek Helio G85 Octa core
# MediaTek Dimensity 6080 Octa core
# MediaTek Helio P35 Octa core
# Unisoc Octa core
# Snapdragon 636 Octa core
# Unisoc Single core
# Snapdragon 665 Octa core
# Snapdragon 870 Octa core
# Snapdragon 695 Octa core
# MediaTek Helio P35 Tru-Octa Core
# Snapdragon 660 Octa core
# Snapdragon 870 Octa core
# MediaTek Helio G85 Octa core
# MediaTek Dimensity 6020 Octa core
# Snapdragon 6 Gen 1 Octa core
# Snapdragon 665 Octa core
# MediaTek Helio G25 Octa core
# MediaTek Dimensity 700 Octa core
# Snapdragon 778G Plus Octa core
# Snapdragon 695 Octa core
# Snapdragon 665 Octa core
# MediaTek Helio G95 Octa core
# MediaTek Helio G85 Octa core
# MediaTek Helio G85 Octa core
# MediaTek Dimensity 810 Octa core
# Snapdragon 732G Octa core
# Snapdragon 7 Gen 3 Octa core
# Samsung Exynos 8 Octa Octa core
# MediaTek Dimensity 1080 Octa core
# Snapdragon 7 Gen 1 Octa core
# MediaTek Dimensity 6300 Octa core
# MediaTek Dimensity 810 Octa core
# Unisoc Tru-Octa Core
# Snapdragon 712 Octa core
# MediaTek Helio G96 Octa core
# MediaTek Dimensity 7200 Octa core
# Unisoc Octa core
# Snapdragon 8 Gen 2 Octa core
# Snapdragon 4 Gen 2 Octa core
# Snapdragon 660 Octa core
# Apple A11 Bionic Hexa Core
# Snapdragon 732G Octa core
# Samsung Exynos Octa core
# Samsung Exynos 9 Octa Octa core
# Snapdragon 778G Octa core
# Snapdragon 4 Gen 1 Octa core
# MediaTek Dimensity 6020 Octa core
# MediaTek Dimensity 8200 Octa core
# MediaTek Dimensity 6300 Octa core
# Snapdragon 888 Octa core
# MediaTek Dimensity 920 Octa core
# Snapdragon 695 Octa core
# Snapdragon 855 Plus Octa core
# Unisoc Octa core
# Snapdragon 710 Octa core
# Snapdragon 778G Octa core
# Snapdragon 778G Octa core
# MediaTek Helio G35 Octa core
# MediaTek Dimensity 6100 Plus Octa core
# MediaTek Dimensity 6300 Octa core
# Snapdragon 6 Gen 1 Octa core
# Snapdragon 865 Octa core
# Samsung Exynos 9 Octa Octa core
# Snapdragon 860 Octa core
# Snapdragon 8 Gen 1 Octa core
# MediaTek Helio P35 Octa core
# MediaTek Dimensity 700 Octa core
# Samsung Exynos 1330 Octa core
# Snapdragon 4 Gen 2 Octa core
# Snapdragon 675 Octa core
# Snapdragon 855 Plus Octa core
# MediaTek Dimensity 8100 Octa core
# MediaTek Dimensity 7050 Octa core
# MediaTek Dimensity 1300 Octa core
# MediaTek Dimensity 930 Octa core
# Snapdragon 8 Gen 3 Octa core
# Unisoc Octa core
# Unisoc
# Snapdragon 675 Octa core
# MediaTek Helio G90T Octa core
# MediaTek Helio G85 Octa core
# MediaTek Helio G85 Octa core
# Snapdragon 732G Octa core
# MediaTek Helio G96 Octa core
# MediaTek Dimensity 700 Octa core
# Snapdragon 8 Plus Gen 1 Octa core
# MediaTek Dimensity 8200 Octa core
# MediaTek Helio G96 Octa core
# Snapdragon 680 Octa core
# MediaTek Helio G35 Octa core
# Snapdragon 8 Gen 2 Octa core
# MediaTek Helio G85 Octa core
# MediaTek Dimensity 1200 Octa core
# MediaTek Dimensity 920 Octa core
# MediaTek Dimensity 6100 Plus Octa core
# MediaTek Helio P65 Octa core
# Samsung Exynos 9 Octa Octa core
# Snapdragon 888 Plus Octa core
# MediaTek Helio G35 Octa core
# Unisoc Octa core
# Snapdragon 680 Octa core
# Snapdragon 680 Octa core
# MediaTek Helio G85 Octa core
# Unisoc Octa core
# Snapdragon 6s 4G Gen 1 Octa core
# MediaTek Helio G90T Octa core
# Snapdragon 865 Octa core
# Samsung Exynos 9 Octa Octa core
# Snapdragon 768G Octa core
# MediaTek Dimensity 810 Octa core
# MediaTek Dimensity 810 Octa core
# Snapdragon 4 Gen 2 Octa core
# Google Tensor G3 Nona Core
# MediaTek Dimensity 6300 Octa core
# MediaTek Helio P35 Tru-Octa Core
# Snapdragon 888 Octa core
# Snapdragon 778G Octa core
# Snapdragon 8 Gen 2 Octa core
# Snapdragon 870 Octa core
# MediaTek Dimensity 7300 Energy Octa core
# Apple A10 Fusion Quad core
# Snapdragon 675 Octa core
# Snapdragon 439 Octa core
# MediaTek Helio P22 Tru-Octa Core
# Snapdragon 865 Octa core
# MediaTek Helio G35 Tru-Octa Core
# Samsung Exynos Octa core
# Samsung Exynos Octa core
# MediaTek Dimensity 810 Octa core
# MediaTek Helio G85 Octa core
# Unisoc Octa core
# MediaTek Tru-Octa Core
# Snapdragon 636 Octa core
# MediaTek Helio P22 Tru-Octa Core
# MediaTek Helio G35 Tru-Octa Core
# Snapdragon 720G Octa core
# MediaTek Dimensity 1000 Plus Octa core
# MediaTek Dimensity 1200 Octa core
# MediaTek Helio G99 Octa core
# MediaTek Dimensity 9300 Octa core
# Snapdragon 712 Octa core
# Snapdragon 888 Plus Octa core
# MediaTek Helio G80 Octa core
# Snapdragon 870 Octa core
# MediaTek Helio G80 Octa core
# MediaTek Dimensity 920 Octa core
# Unisoc Octa core
# Apple A9 Dual core
# Apple A10 Fusion Quad core
# Samsung Exynos 9 Octa Octa core
# Snapdragon 665 Octa core
# MediaTek Dimensity 800U Octa core
# Snapdragon 888 Octa core
# MediaTek Helio A25 Octa core
# Snapdragon 865 Octa core
# Snapdragon 730G Octa core
# Snapdragon 720G Octa core
# Snapdragon 662 Octa core
# MediaTek Dimensity 700 Octa core
# MediaTek Helio G99 Octa core
# MediaTek Dimensity 7300 Energy Octa core
# Apple A18 Hexa Core
# Snapdragon 712 Octa core
# Samsung Exynos 7 Octa Octa core
# Snapdragon 665 Octa core
# Samsung Exynos 9 Octa Octa core
# Snapdragon 750G Octa core
# Unisoc Octa core
# MediaTek Helio G36 Octa core
# Unisoc Octa core
# MediaTek Dimensity 6300 Octa core
# Unisoc Tru-Octa Core
# MediaTek Helio P60 Octa core
# Samsung Exynos 7 Octa Octa core
# MediaTek Helio G70 Octa core
# MediaTek Helio G80 Octa core
# MediaTek Helio G35 Tru-Octa Core
# Snapdragon 695 Octa core
# MediaTek Helio G96 Octa core
# MediaTek Helio G88 Octa core
# Unisoc Octa core
# MediaTek Dimensity 7050 Octa core
# MediaTek Dimensity 6300 Octa core
# Snapdragon 730 Octa core
# MediaTek Dimensity 800U Octa core
# MediaTek Helio G96 Octa core
# MediaTek Dimensity 810 Octa core
# Unisoc Octa core
# Samsung Exynos 3 Quad Quad core
# MediaTek Helio P65 Octa core
# Snapdragon 439 Octa core
# Samsung Exynos 8 Octa Octa core
# Apple A17 Pro Hexa Core
# Snapdragon 8 Gen 3 Octa core
# Unisoc Octa core
# Snapdragon 450 Tru-Octa Core
# Snapdragon 845 Octa core
# Snapdragon 665 Octa core
# Snapdragon 730G Octa core
# Snapdragon 765G Octa core
# MediaTek Dimensity 920 Octa core
# Unisoc Octa core
# MediaTek Helio P35 Octa core
# Snapdragon 685 Octa core
# Samsung Exynos 2400 Deca Core
# MediaTek Dimensity 8020 Octa core
# MediaTek Dimensity 700 Octa core
# MediaTek Dimensity 700 Octa core
# Snapdragon 888 Octa core
# MediaTek Dimensity 800U Octa core
# MediaTek Helio G88 Octa core
# MediaTek Helio P22 Tru-Octa Core
# MediaTek Dimensity 700 Octa core
# Unisoc Single core
# MediaTek Dimensity 6020 Octa core
# Unisoc Octa core
# Snapdragon 7s Gen 2 Octa core
# MediaTek Helio G36 Octa core
# MediaTek Dimensity 7300 Energy Octa core
# Unisoc Octa core
# Snapdragon 210 Quad core
# Samsung Exynos 7 Octa Octa core
# MediaTek Helio P35 Tru-Octa Core
# MediaTek Helio P35 Octa core
# Unisoc Tru-Octa Core
# Samsung Exynos 8 Octa Tru-Octa Core
# Snapdragon 680 Octa core
# Apple A16 Bionic Hexa Core
# Apple A18 Pro Hexa Core
# Spreadtrum Quad core
# Snapdragon 660 Octa core
# Samsung Exynos 9 Octa Octa core
# Snapdragon 855 Plus Octa core
# Snapdragon 865 Plus Octa core
# Snapdragon 665 Octa core
# MediaTek Helio G80 Octa core
# Snapdragon 750G Octa core
# Snapdragon 480 Octa core
# MediaTek Helio G85 Octa core
# MediaTek Dimensity 720 Octa core
# MediaTek Helio G88 Octa core
# Unisoc Octa core
# Snapdragon 680 Octa core
# Snapdragon 695 Octa core
# MediaTek Helio G85 Octa core
# MediaTek Helio P35 Octa core
# MediaTek Dimensity 6020 Octa core
# Apple A8 Dual core
# Snapdragon 660 Octa core
# MediaTek Helio P35 Tru-Octa Core
# MediaTek Helio G35 Tru-Octa Core
# Snapdragon 665 Octa core
# Snapdragon 888 Octa core
# Snapdragon 480 Octa core
# Unisoc Octa core
# Snapdragon 732G Octa core
# Apple A15 Bionic Hexa Core
# MediaTek Dimensity 900 Octa core
# Snapdragon 695 Octa core
# MediaTek Helio A22 Quad core
# MediaTek Helio G37 Octa core
# Unisoc Octa core
# Apple A11 Bionic Hexa Core
# MediaTek Quad core
# Snapdragon 712 Octa core
# Snapdragon 865 Octa core
# Snapdragon 855 Octa core
# MediaTek Helio G80 Octa core
# Snapdragon 888 Octa core
# MediaTek Helio G95 Octa core
# Snapdragon 662 Octa core
# MediaTek Helio G99 Octa core
# Snapdragon 695 Octa core
# Snapdragon 8 Gen 2 Octa core
# MediaTek Helio G36 Octa core
# Google Tensor G3 Nona Core
# Samsung Exynos 1330 Octa core
# MediaTek Dimensity 6100 Plus Octa core
# MediaTek Helio G85 Octa core
# Unisoc Tru-Octa Core
# Snapdragon 810 Octa core
# Snapdragon 845 Octa core
# Snapdragon 439 Octa core
# Snapdragon 712 Octa core
# Snapdragon 675 Octa core
# Snapdragon 845 Octa core
# Snapdragon 730G Octa core
# Samsung Exynos 9 Octa Octa core
# MediaTek Helio P35 Octa core
# MediaTek Dimensity 700 Octa core
# Unisoc Octa core
# MediaTek Dimensity 9000 Plus Octa core
# MediaTek Dimensity 9000 Octa core
# MediaTek Dimensity 6020 Octa core
# Snapdragon 8 Gen 3 Octa core
# Unisoc Tru-Octa Core
# Samsung Exynos 8 Octa Octa core
# Samsung Exynos 9 Octa Octa core
# Snapdragon 845 Octa core
# Snapdragon 625 Tru-Octa Core
# MediaTek Helio P70 Octa core
# Snapdragon 865 Plus Octa core
# Snapdragon 450 Tru-Octa Core
# MediaTek Helio P22 Tru-Octa Core
# MediaTek Helio P35 Tru-Octa Core
# Snapdragon 662 Octa core
# MediaTek Helio G25 Tru-Octa Core
# Unisoc Octa core
# MediaTek Dimensity 1200 Octa core
# MediaTek Helio G96 Octa core
# Unisoc Tru-Octa Core
# Snapdragon 888 Octa core
# Samsung Exynos Tru-Octa Core
# Snapdragon 680 Octa core
# Snapdragon 8s Gen 3 Octa core
# Unisoc Tru-Octa Core
# MediaTek Octa core
# Snapdragon 730G Octa core
# MediaTek Helio P22 Tru-Octa Core
# MediaTek Helio G90T Octa core
# MediaTek Helio G85 Octa core
# MediaTek Helio G80 Octa core
# Snapdragon 888 Plus Octa core
# MediaTek Helio G85 Octa core
# MediaTek Dimensity 1200 Octa core
# Snapdragon 480 Plus Octa core
# MediaTek Helio G37 Octa core
# Snapdragon 8 Gen 1 Octa core
# Snapdragon 778G Octa core
# Snapdragon 778G Plus Octa core
# Samsung Exynos Octa core
# Unisoc Octa core
# MediaTek Helio G85 Octa core
# MediaTek Dimensity 6080 Octa core
# MediaTek Dimensity 6100 Plus Octa core
# MediaTek Dimensity 6020 Octa core
# MediaTek Dimensity 6300 Octa core
# Samsung Exynos 7 Octa Tru-Octa Core
# Snapdragon 865 Octa core
# Snapdragon 712 Octa core
# Snapdragon 730G Octa core
# MediaTek Quad core
# Samsung Exynos 9 Octa Octa core
# Snapdragon 750G Octa core
# MediaTek Helio G95 Octa core
# Snapdragon 680 Octa core
# Snapdragon 680 Octa core
# MediaTek Helio G96 Octa core
# Snapdragon 8 Gen 1 Octa core
# Unisoc Octa core
# Samsung Exynos 8 Octa Tru-Octa Core
# MediaTek Dimensity 7050 Octa core
# MediaTek Dimensity 6020 Octa core
# MediaTek Dimensity 6100 Plus Octa core
# MediaTek Dimensity 6020 Octa core
# Samsung Exynos 2400 Deca Core
# MediaTek Helio G85 Octa core
# Snapdragon 8s Gen 3 Octa core
# MediaTek Dimensity 6300 Octa core
# MediaTek Dimensity 6080 Octa core
# MediaTek Dimensity 7050 Octa core
# Snapdragon 801
# MediaTek Helio P22 Tru-Octa Core
# HiSilicon Kirin Octa core
# MediaTek Helio A22 Quad core
# Snapdragon 730G Octa core
# MediaTek Helio P22 Tru-Octa Core
# Snapdragon 439 Octa core
# Apple A13 Bionic Hexa Core
# Snapdragon 720G Octa core
# MediaTek Helio G35 Tru-Octa Core
# MediaTek Helio G95 Octa core
# Snapdragon 750G Octa core
# Snapdragon 870 Octa core
# Spreadtrum Dual core
# MediaTek Dimensity 920 Octa core
# Snapdragon 695 Octa core
# Snapdragon 778G Plus Octa core
# MediaTek Dimensity 9200 Octa core
# MediaTek Helio G88 Octa core
# MediaTek Helio P35 Octa core
# Snapdragon 778G Octa core
# Samsung Exynos Octa core
# MediaTek Dimensity 6100 Plus Octa core
# Snapdragon 7 Gen 3 Octa core
# Unisoc Octa core
# MediaTek Dimensity 6300 Octa core
# Google Tensor G4 Octa core
# Unisoc Octa core
# Snapdragon 625 Tru-Octa Core
# Samsung Exynos 7 Octa Octa core
# Samsung Exynos 7 Octa Tru-Octa Core
# Snapdragon 450 Tru-Octa Core
# Snapdragon 710 Octa core
# MediaTek Helio P22 Tru-Octa Core
# Snapdragon 855 Octa core
# Snapdragon 855 Plus Octa core
# Snapdragon 665 Octa core
# Snapdragon 665 Octa core
# Snapdragon 675 Octa core
# Snapdragon 665 Octa core
# Snapdragon 439 Octa core
# MediaTek Helio G35 Tru-Octa Core
# MediaTek Helio P22 Tru-Octa Core
# Snapdragon 662 Octa core
# Snapdragon 888 Octa core
# Snapdragon 888 Octa core
# Unisoc Octa core
# Snapdragon 888 Octa core
# Snapdragon 778G Octa core
# Unisoc Octa core
# Snapdragon 680 Octa core
# Snapdragon 695 Octa core
# Snapdragon 680 Octa core
# MediaTek Dimensity 8100 Octa core
# Snapdragon 8 Plus Gen 1 Octa core
# Snapdragon 8 Plus Gen 1 Octa core
# Snapdragon 4 Gen 1 Octa core
# MediaTek Helio G36 Octa core
# Snapdragon 695 Octa core
# MediaTek Helio P35 Octa core
# MediaTek Helio G35 Tru-Octa Core
# Samsung Exynos Octa core
# Apple A17 Pro Hexa Core
# Apple A17 Pro Hexa Core
# Snapdragon 8 Plus Gen 1 Octa core
# Unisoc Octa core
# Snapdragon 680 Octa core
# MediaTek Dimensity 6300 Octa core
# Snapdragon 8 Gen 3 Octa core
# Apple A7 Dual core
# Snapdragon 210
# Snapdragon 625 Tru-Octa Core
# Snapdragon 835 Octa core
# MediaTek Helio A22 Quad core
# Snapdragon 845 Octa core
# Snapdragon 632 Octa core
# MediaTek Helio P60 Octa core
# MediaTek Helio P35 Tru-Octa Core
# Unisoc
# Snapdragon 665 Octa core
# MediaTek Helio G70 Octa core
# MediaTek Dimensity 700 Octa core
# Snapdragon 778G Octa core
# Apple A15 Bionic Hexa Core
# MediaTek
# MediaTek Dimensity 810 Octa core
# MediaTek Helio G99 Octa core
# MediaTek Dimensity 900 Octa core
# Apple A15 Bionic Hexa Core
# Snapdragon 8 Gen 1 Octa core
# Unisoc Octa core
# MediaTek Helio G85 Octa core
# Snapdragon 8 Plus Gen 1 Octa core
# MediaTek Helio P22 Tru-Octa Core
# Apple A15 Bionic Hexa Core
# MediaTek Helio P35 Octa core
# Snapdragon 695 Octa core
# MediaTek Dimensity 1080 Octa core
# MediaTek Dimensity 1080 Octa core
# MediaTek Helio G88 Octa core
# Samsung Exynos 1330 Octa core
# MediaTek Dimensity 7050 Octa core
# MediaTek Helio G36 Octa core
# MediaTek
# Samsung Exynos 7 Octa Octa core
# Samsung Exynos 9 Octa Octa core
# MediaTek Helio P22 Tru-Octa Core
# Snapdragon 660 Octa core
# MediaTek Helio P70 Octa core
# Snapdragon 710 Octa core
# Snapdragon 660 Octa core
# Snapdragon 665 Octa core
# Samsung Exynos 9 Octa Octa core
# Snapdragon 720G Octa core
# MediaTek Helio P35 Tru-Octa Core
# Snapdragon 720G Octa core
# Apple A14 Bionic Hexa Core
# MediaTek Helio G95 Octa core
# MediaTek Helio G80 Octa core
# MediaTek Helio G25 Octa core
# MediaTek Helio P35 Tru-Octa Core
# Snapdragon 430 Tru-Octa Core
# MediaTek Helio G95 Octa core
# MediaTek Dimensity 900 Octa core
# MediaTek Helio G35 Octa core
# Snapdragon 870 Octa core
# MediaTek Dimensity 1080 Octa core
# MediaTek Dimensity 1080 Octa core
# Unisoc Octa core
# MediaTek
# Unisoc Octa core
# Snapdragon 8 Gen 2 Octa core
# MediaTek Dimensity 6080 Octa core
# Snapdragon 695 Octa core
# Snapdragon 680 Octa core
# Snapdragon 425 Quad core
# MediaTek Octa core
# Snapdragon 8 Gen 3 Octa core
# MediaTek Helio G36 Octa core
# Snapdragon 4 Gen 2 Octa core
# Snapdragon S4 Plus
# Snapdragon 415 Tru-Octa Core
# Snapdragon 625 Tru-Octa Core
# Samsung Exynos 7 Octa Tru-Octa Core
# Snapdragon 636 Octa core
# MediaTek Octa core
# Snapdragon 636 Octa core
# Snapdragon 845 Octa core
# Snapdragon 675 Octa core
# Snapdragon 439 Octa core
# Snapdragon 205 Dual core
# Snapdragon 720G Octa core
# Snapdragon 730G Octa core
# Apple A13 Bionic Hexa Core
# Snapdragon 662 Octa core
# Unisoc
# MediaTek Helio A20 Quad core
# MediaTek Helio G70 Octa core
# Unisoc Octa core
# MediaTek Helio G35 Tru-Octa Core
# Spreadtrum Quad core
# MediaTek Dimensity 1200 Octa core
# MediaTek Helio P35 Octa core
# Snapdragon 680 Octa core
# Snapdragon 695 Octa core
# MediaTek Helio P35 Octa core
# Unisoc Octa core
# MediaTek Helio G85 Octa core
# Snapdragon 870 Octa core
# Snapdragon 8 Plus Gen 1 Octa core
# Unisoc Single core
# Apple A15 Bionic Hexa Core
# MediaTek Helio A22 Quad core
# MediaTek Helio P60 Octa core
# Snapdragon 680 Octa core
# Samsung Exynos 1330 Octa core
# MediaTek Dimensity 7050 Octa core
# Snapdragon 8 Plus Gen 1 Octa core
# Snapdragon 4 Gen 2 Octa core
# MediaTek Dimensity 6020 Octa core
# MediaTek Dimensity 6100 Plus Octa core
# MediaTek Helio G85 Octa core
# MediaTek Helio G36 Octa core
# MediaTek Dimensity 6100 Plus Octa core
# MediaTek Dimensity 6300 Octa core
# Apple A18 Hexa Core
# MediaTek
# Snapdragon 410 Quad core
# MediaTek Octa core
# Snapdragon 653 Octa core
# Snapdragon 212 Quad core
# MediaTek Deca Core
# MediaTek Helio P60 Octa core
# Snapdragon 845 Octa core
# Samsung Exynos 7 Octa Octa core
# MediaTek Helio P22 Tru-Octa Core
# Samsung Exynos 8 Octa Octa core
# MediaTek Helio G35 Tru-Octa Core
# Snapdragon 855 Plus Octa core
# Apple A14 Bionic Hexa Core
# Snapdragon 662 Octa core
# Snapdragon 450 Tru-Octa Core
# MediaTek Helio P35 Tru-Octa Core
# Snapdragon 870 Octa core
# MediaTek Dimensity 700 Octa core
# MediaTek Helio A20 Quad core
# MediaTek Helio G80 Octa core
# MediaTek Dimensity 1200 Octa core
# MediaTek Helio G35 Tru-Octa Core
# Snapdragon 439 Octa core
# Snapdragon 680 Octa core
# Snapdragon 888 Octa core
# Snapdragon 888 Octa core
# Snapdragon 695 Octa core
# Samsung Exynos Octa core
# MediaTek Dimensity 8100 Octa core
# Snapdragon 8 Plus Gen 1 Octa core
# Unisoc Octa core
# Snapdragon 870 Octa core
# Snapdragon 695 Octa core
# MediaTek Dimensity 8200 Octa core
# Snapdragon 695 Octa core
# Unisoc Octa core
# MediaTek Helio G85 Octa core
# Spreadtrum Quad core
# ST-Ericsson NovaThor
# Snapdragon 7s Gen 2 Octa core
# MediaTek Dimensity 7050 Octa core
# Apple A18 Pro Hexa Core
# MediaTek Dimensity 6100 Plus Octa core
# Snapdragon 800 Quad core
# MediaTek Quad core
# Snapdragon 200
# Apple A9 Dual core
# Snapdragon 820 Quad core
# Snapdragon 625 Tru-Octa Core
# Snapdragon 835 Octa core
# Snapdragon 835 Octa core
# Snapdragon 425 Quad core
# Snapdragon 835 Octa core
# MediaTek Quad core
# Snapdragon 626 Tru-Octa Core
# Snapdragon 845 Octa core
# Apple A12 Bionic Hexa Core
# Samsung Exynos 7 Octa Tru-Octa Core
# MediaTek Helio P22 Tru-Octa Core
# Snapdragon 636 Octa core
# Samsung Exynos 7 Octa Octa core
# MediaTek Helio P60 Octa core
# Snapdragon 660 Octa core
# Snapdragon 425 Quad core
# Snapdragon 675 Octa core
# Snapdragon 865 Octa core
# Snapdragon 665 Octa core
# Snapdragon 460 Octa core
# MediaTek Helio G80 Octa core
# Snapdragon 865 Octa core
# Snapdragon 460 Octa core
# MediaTek Helio G35 Tru-Octa Core
# Snapdragon 662 Octa core
# MediaTek Helio G85 Octa core
# Snapdragon 732G Octa core
# MediaTek Helio G70 Octa core
# Snapdragon 732G Octa core
# MediaTek Dimensity 700 Octa core
# Snapdragon 750G Octa core
# MediaTek Dimensity 700 Octa core
# Snapdragon 750G Octa core
# Samsung Exynos 9 Octa Octa core
# MediaTek Dimensity 700 Octa core
# MediaTek Dimensity 700 Octa core
# MediaTek Helio G35 Octa core
# MediaTek Helio G35 Tru-Octa Core
# Snapdragon 888 Octa core
# MediaTek Helio G96 Octa core
# Snapdragon 8 Gen 1 Octa core
# Unisoc Octa core
# Snapdragon 888 Octa core
# Snapdragon 8 Gen 1 Octa core
# MediaTek Dimensity 9000 Octa core
# MediaTek Helio G35 Octa core
# MediaTek Helio G99 Octa core
# Apple A16 Bionic Hexa Core
# MediaTek Dimensity 900 Octa core
# MediaTek Helio G88 Octa core
# MediaTek Helio P35 Octa core
# Snapdragon 8 Gen 2 Octa core
# Unisoc Octa core
# MediaTek Dimensity 920 Octa core
# MediaTek Dimensity 8050 Octa core
# Unisoc Octa core
# Spreadtrum
# Snapdragon 450 Tru-Octa Core
# MediaTek Dimensity 7050 Octa core
# MediaTek Helio G85 Octa core
# Unisoc Octa core
# MediaTek Dimensity 7200 Ultra Octa core
# MediaTek Dimensity 7020 Octa core
# Unisoc Octa core
# Snapdragon 8 Gen 3 Octa core
# MediaTek Dimensity 6300 Octa core
# MediaTek Dimensity 6100 Plus Octa core
# Unisoc Octa core
# Snapdragon 801 Quad core
# Snapdragon 801 Quad core
# Apple A8 Dual core
# Snapdragon S4 Plus
# Samsung Exynos 3 Quad Quad core
# MediaTek Octa core
# Snapdragon 400 Quad core
# Snapdragon 430 Tru-Octa Core
# MediaTek Quad core
# Spreadtrum Quad core
# Snapdragon 821 Quad core
# Snapdragon 435 Tru-Octa Core
# Snapdragon 835 Octa core
# MediaTek Octa core
# Snapdragon 660 Octa core
# Snapdragon 450 Tru-Octa Core
# Samsung Exynos 9 Octa Octa core
# MediaTek Quad core
# MediaTek Quad core
# Samsung Exynos 7 Octa Tru-Octa Core
# Snapdragon 625 Tru-Octa Core
# Snapdragon 450 Tru-Octa Core
# HiSilicon Kirin Octa core
# HiSilicon Kirin Octa core
# Snapdragon 855 Octa core
# MediaTek Helio P70 Octa core
# Snapdragon 675 Octa core
# Snapdragon 855 Plus Octa core
# Snapdragon 712 Octa core
# Snapdragon 665 Octa core
# MediaTek Helio G90T Octa core
# Snapdragon 730 Octa core
# MediaTek Helio P22 Tru-Octa Core
# MediaTek Helio A22 Quad core
# Snapdragon 460 Octa core
# Snapdragon 720G Octa core
# Snapdragon 662 Octa core
# MediaTek Helio G95 Octa core
# Apple A14 Bionic Hexa Core
# Snapdragon 730 Octa core
# Samsung Exynos 2100 Octa core
# MediaTek Dimensity 800U Octa core
# Snapdragon 662 Octa core
# Snapdragon 460 Octa core
# Snapdragon 720G Octa core
# Snapdragon 450 Tru-Octa Core
# MediaTek Helio G85 Octa core
# Unisoc Octa core
# Snapdragon 768G Octa core
# MediaTek Dimensity 1200 Octa core
# Snapdragon 888 Plus Octa core
# Snapdragon 888 Octa core
# MediaTek Dimensity 810 Octa core
# Snapdragon 439 Octa core
# MediaTek Helio G88 Octa core
# Apple A15 Bionic Hexa Core
# HiSilicon Kirin Octa core
# Unisoc Tru-Octa Core
# MediaTek Helio A22 Quad core
# Unisoc Tru-Octa Core
# MediaTek Helio G70 Octa core
# MediaTek Dimensity 8100 Max Octa core
# MediaTek Helio A22 Quad core
# Samsung Exynos 8 Octa Octa core
# MediaTek Dimensity 1300 Octa core
# Unisoc Octa core
# MediaTek Helio A22 Quad core
# MediaTek Dimensity 700 Octa core
# Unisoc Octa core
# Snapdragon 778G Octa core
# Snapdragon 8 Gen 2 Octa core
# MediaTek Dimensity 700 Octa core
# MediaTek Helio G70 Octa core
# MediaTek Dimensity 6020 Octa core
# MediaTek Dimensity 6020 Octa core
# MediaTek Dimensity 6100 Plus Octa core
# MediaTek Helio P90 Octa core
# MediaTek Dimensity 6100 Plus Octa core
# Unisoc Tru-Octa Core
# Unisoc Octa core
# MediaTek Dimensity 6100 Plus Octa core
# Snapdragon 6 Gen 1 Octa core
# MediaTek Dimensity 7050 Octa core
# MediaTek Dimensity 6300 Octa core
# MediaTek Dimensity 7300 Energy Octa core
# Apple A18 Hexa Core
# Apple A18 Pro Hexa Core
# Unisoc Octa core
# Snapdragon S2 Single core
# Snapdragon S4 Plus
# Snapdragon 400
# MediaTek
# Apple A6 Dual core
# MediaTek Octa core
# MediaTek Quad core
# Snapdragon 410 Quad core
# MediaTek Octa core
# MediaTek Quad core
# MediaTek Octa core
# MediaTek Tru-Octa Core
# Snapdragon 617 Octa core
# HiSilicon Kirin Octa core
# Spreadtrum Quad core
# Apple A11 Bionic Hexa Core
# MediaTek Quad core
# Snapdragon 210 Quad core
# HiSilicon Kirin Octa core
# Snapdragon 427 Quad core
# Snapdragon 205 Dual core
# Snapdragon 450 Tru-Octa Core
# Snapdragon 625 Tru-Octa Core
# Samsung Exynos 9 Octa Octa core
# Snapdragon 625 Tru-Octa Core
# Snapdragon 632 Octa core
# Snapdragon 632 Octa core
# MediaTek Quad core
# Apple A12 Bionic Hexa Core
# HiSilicon Kirin Octa core
# Snapdragon 660 Octa core
# MediaTek Quad core
# Snapdragon 450 Tru-Octa Core
# Snapdragon 450 Tru-Octa Core
# Samsung Exynos 7 Octa Octa core
# Snapdragon 632 Octa core
# Snapdragon 710 Octa core
# Snapdragon 855 Octa core
# Snapdragon 439 Octa core
# MediaTek Helio A22 Quad core
# Snapdragon 730 Octa core
# Snapdragon 630 Tru-Octa Core
# MediaTek Helio P22 Tru-Octa Core
# Snapdragon 710 Octa core
# Snapdragon 855 Plus Octa core
# Samsung Exynos 9 Octa Octa core
# Snapdragon 855 Plus Octa core
# Snapdragon 662 Octa core
# Snapdragon 720G Octa core
# MediaTek Helio G90T Octa core
# Snapdragon 750G Octa core
# Snapdragon 665 Octa core
# Snapdragon 460 Octa core
# Snapdragon 732G Octa core
# Snapdragon 662 Octa core
# Samsung Exynos 8 Octa Octa core
# MediaTek Helio P95 Octa core
# MediaTek Helio A20 Quad core
# MediaTek Dimensity 800U Octa core
# MediaTek Helio P95 Octa core
# Samsung Exynos 8 Octa Tru-Octa Core
# MediaTek Helio A25 Octa core
# MediaTek Dimensity 800U Octa core
# MediaTek Dimensity 700 Octa core
# Unisoc
# Snapdragon 662 Octa core
# MediaTek Helio A20 Quad core
# Unisoc Octa core
# Snapdragon 720G Octa core
# MediaTek Helio G85 Octa core
# Snapdragon 778G Octa core
# Unisoc Octa core
# Apple A15 Bionic Hexa Core
# Apple A15 Bionic Hexa Core
# Unisoc Tru-Octa Core
# Snapdragon 778G Octa core
# MediaTek Helio P22 Tru-Octa Core
# Spreadtrum Quad core
# MediaTek Tru-Octa Core
# MediaTek Helio A22 Quad core
# MediaTek Helio G25 Octa core
# MediaTek Helio A25 Octa core
# MediaTek Dimensity 810 Octa core
# MediaTek Dimensity 920 Octa core
# Snapdragon 680 Octa core
# MediaTek Helio G88 Octa core
# MediaTek Helio G37 Octa core
# Snapdragon 680 Octa core
# MediaTek Helio G96 Octa core
# Snapdragon 778G Octa core
# Snapdragon 695 Octa core
# Samsung Exynos 8 Octa Tru-Octa Core
# Snapdragon 778G Octa core
# Snapdragon 695 Octa core
# Snapdragon 680 Octa core
# MediaTek Helio P35 Octa core
# Unisoc Octa core
# Unisoc Octa core
# MediaTek Helio A22 Quad core
# Unisoc Single core
# MediaTek Helio G99 Octa core
# MediaTek Helio G25 Octa core
# MediaTek Dimensity 920 Octa core
# MediaTek Helio G99 Octa core
# MediaTek Dimensity 810 Octa core
# MediaTek Dimensity 8200 Octa core
# MediaTek Dimensity 6020 Octa core
# Snapdragon 4 Gen 1 Octa core
# MediaTek Helio A22 Quad core
# MediaTek Dimensity 6020 Octa core
# Unisoc Octa core
# MediaTek Helio G36 Octa core
# Unisoc Octa core
# Snapdragon 8 Gen 2 Octa core
# MediaTek Tru-Octa Core
# Snapdragon S1
# Samsung Exynos Octa core
# Snapdragon 6 Gen 1 Octa core
# MediaTek Helio G85 Octa core
# MediaTek Helio G25 Octa core
# MediaTek Dimensity 6300 Octa core
# MediaTek Dimensity 7020 Octa core
# Unisoc Tru-Octa Core
# Snapdragon S1
# Snapdragon 800
# Samsung Exynos 5 Octa core
# Snapdragon 200
# Apple A8 Dual core
# Apple A8 Dual core
# Snapdragon 410
# MediaTek Tru-Octa Core
# Snapdragon 210
# MediaTek Tru-Octa Core
# Apple A9 Dual core
# Snapdragon 210
# HiSilicon Kirin Octa core
# Snapdragon 820 Quad core
# Spreadtrum Quad core
# Samsung Exynos 7 Octa Tru-Octa Core
# Snapdragon 625 Tru-Octa Core
# Snapdragon 835 Octa core
# MediaTek Octa core
# Snapdragon 450 Tru-Octa Core
# MediaTek Tru-Octa Core
# MediaTek Quad core
# Spreadtrum Quad core
# Snapdragon 430 Tru-Octa Core
# HiSilicon Kirin Octa core
# Snapdragon 835 Octa core
# Snapdragon 835 Octa core
# Snapdragon 430 Tru-Octa Core
# Snapdragon 653 Octa core
# MediaTek Tru-Octa Core
# Snapdragon 425 Quad core
# MediaTek Quad core
# Snapdragon 636 Octa core
# MediaTek Quad core
# Snapdragon 430 Tru-Octa Core
# Snapdragon 430 Tru-Octa Core
# Snapdragon 636 Octa core
# Snapdragon 450 Tru-Octa Core
# Snapdragon 625 Tru-Octa Core
# Snapdragon 425 Quad core
# HiSilicon Kirin Octa core
# Snapdragon 845 Octa core
# MediaTek Helio P22 Tru-Octa Core
# Snapdragon 845 Octa core
# HiSilicon Kirin Octa core
# MediaTek Helio A22 Quad core
# MediaTek Helio P22 Tru-Octa Core
# Snapdragon 660 Octa core
# Apple A12 Bionic Hexa Core
# Snapdragon 845 Octa core
# Snapdragon 632 Octa core
# Snapdragon 660 Octa core
# Snapdragon 660 Octa core
# MediaTek Helio P70 Octa core
# Snapdragon 636 Octa core
# MediaTek Octa core
# Snapdragon 710 Octa core
# Samsung Exynos 9 Octa Octa core
# MediaTek Helio P70 Octa core
# MediaTek Helio P35 Tru-Octa Core
# Samsung Exynos 9 Octa Octa core
# MediaTek Helio P22 Tru-Octa Core
# Snapdragon 665 Octa core
# Snapdragon 450 Tru-Octa Core
# Apple A13 Bionic Hexa Core
# Apple A13 Bionic Hexa Core
# Snapdragon 712 Octa core
# MediaTek Helio P35 Tru-Octa Core
# MediaTek Helio P22 Tru-Octa Core
# Snapdragon 855 Plus Octa core
# Snapdragon 720G Octa core
# MediaTek Helio A25 Octa core
# Snapdragon 730 Octa core
# Snapdragon 720G Octa core
# MediaTek Helio P35 Tru-Octa Core
# ...
# MediaTek Dimensity 700 Octa core
# Samsung Exynos 9 Octa Octa core
# MediaTek Dimensity 1200 Octa core
# Unisoc Tru-Octa Core
# MediaTek Dimensity 800U Octa core
# Snapdragon 888 Octa core
# Snapdragon 888 Octa core
# MediaTek Helio A25 Octa core
# MediaTek Helio G85 Octa core
# MediaTek Helio G96 Octa core
# Apple A15 Bionic Hexa Core
# Apple A15 Bionic Hexa Core
# Apple A15 Bionic Hexa Core
# MediaTek Helio G35 Tru-Octa Core
# MediaTek Helio G35 Tru-Octa Core
# Snapdragon 720G Octa core
# Snapdragon 720G Octa core
# Samsung Exynos 9 Octa Octa core
# Snapdragon 720G Octa core
# MediaTek Helio P22 Tru-Octa Core
# Snapdragon 720G Octa core
# MediaTek Helio G90T Octa core
# MediaTek Helio P35 Tru-Octa Core
# Snapdragon 865 Octa core
# Snapdragon 865 Octa core
# Snapdragon 665 Octa core
# MediaTek Quad core
# MediaTek Octa core
# MediaTek Quad core
# MediaTek Octa core
# Spreadtrum
# Spreadtrum Quad core
# Snapdragon 625 Tru-Octa Core
# MediaTek Quad core
# HiSilicon Kirin Octa core
# Snapdragon 615 Octa core
# Snapdragon 200 Quad core
# MediaTek Quad core
# MediaTek Octa core
# Spreadtrum
# MediaTek Tru-Octa Core
# MediaTek Quad core
# Intel Atom Quad core
# Spreadtrum
# MediaTek
# Snapdragon 400
# Snapdragon 400 Quad core
# Snapdragon 800
# Snapdragon 662 Octa core
# Unisoc Octa core
# MediaTek Helio G95 Octa core
# MediaTek Dimensity 1200 Octa core
# MediaTek Helio G25 Octa core
# MediaTek Dimensity 810 Octa core
# MediaTek Dimensity 920 Octa core
# Unisoc Octa core
# MediaTek Helio G35 Octa core
# MediaTek Helio G35 Octa core
# Snapdragon 695 Octa core
# Snapdragon 695 Octa core
# Snapdragon 680 Octa core
# Unisoc Quad core
# MediaTek Dimensity 920 Octa core
# MediaTek Dimensity 920 Octa core
# Snapdragon 888 Plus Octa core
# MediaTek Helio G96 Octa core
# MediaTek Helio G96 Octa core
# Unisoc Octa core
# Apple A15 Bionic Hexa Core
# Snapdragon 695 Octa core
# MediaTek Dimensity 810 Octa core
# Unisoc Quad core
# MediaTek Helio P22 Tru-Octa Core
# Snapdragon 680 Octa core
# MediaTek Helio G25 Quad core
# Unisoc Octa core
# Unisoc Octa core
# MediaTek Helio P35 Octa core
# MediaTek Helio G25 Octa core
# MediaTek Helio G99 Octa core
# Unisoc Tru-Octa Core
# Unisoc Octa core
# Snapdragon 680 Octa core
# Snapdragon 680 Octa core
# MediaTek Helio P35 Octa core
# MediaTek Dimensity 810 Octa core
# Snapdragon 680 Octa core
# MediaTek Helio G37 Octa core
# MediaTek Helio G37 Octa core
# MediaTek Helio G85 Octa core
# MediaTek Dimensity 810 Octa core
# MediaTek Helio G99 Octa core
# Snapdragon 680 Octa core
# MediaTek Helio G37 Octa core
# Snapdragon 8 Plus Gen 1 Octa core
# Snapdragon 8 Plus Gen 1 Octa core
# Snapdragon 8 Plus Gen 1 Octa core
# MediaTek Dimensity 810 Octa core
# Unisoc Octa core
# Apple A15 Bionic Hexa Core
# Apple A15 Bionic Hexa Core
# Apple A16 Bionic Hexa Core
# Apple A16 Bionic Hexa Core
# MediaTek Helio G37 Octa core
# MediaTek Helio G70 Octa core
# Unisoc Octa core
# MediaTek Helio A22 Quad core
# MediaTek Helio G37 Octa core
# MediaTek
# MediaTek Helio A22 Quad core
# MediaTek Helio P35 Octa core
# MediaTek Helio G37 Octa core
# MediaTek Dimensity 8100 Max Octa core
# MediaTek Helio G80 Octa core
# MediaTek Helio G80 Octa core
# MediaTek Dimensity 1080 Octa core
# MediaTek Dimensity 1080 Octa core
# Samsung Exynos Tru-Octa Core
# MediaTek Helio A22 Quad core
# Unisoc Octa core
# MediaTek Helio A22 Quad core
# MediaTek Helio G37 Octa core
# MediaTek Dimensity 8200 Octa core
# Unisoc Octa core
# MediaTek Helio G85 Octa core
# MediaTek Helio G37 Octa core
# MediaTek Dimensity 700 Octa core
# Unisoc Octa core
# Unisoc Octa core
# MediaTek Helio G36 Octa core
# MediaTek Dimensity 7050 Octa core
# Unisoc Octa core
# Unisoc Octa core
# Unisoc Octa core
# Apple A16 Bionic Hexa Core
# MediaTek Helio G85 Octa core
# Unisoc Octa core
# Unisoc Octa core
# Unisoc Octa core
# Snapdragon 712 Octa core
# MediaTek Dual core
# Snapdragon 810 Octa core
# Snapdragon 801
# Snapdragon S1
# Snapdragon S2
# MediaTek Helio G85 Octa core
# Unisoc Octa core
# Unisoc Octa core
# Unisoc Octa core
# Unisoc Octa core
# Unisoc Octa core
# Unisoc Octa core
# MediaTek Dimensity 8020 Octa core
# MediaTek Dimensity 6080 Octa core
# MediaTek Dimensity 7050 Octa core
# MediaTek Dimensity 6300 Octa core
# Unisoc Tru-Octa Core
# MediaTek Dimensity 6300 Octa core
# MediaTek Dimensity 6100 Plus Octa core
# Unisoc Octa core
# Snapdragon 650 Hexa Core
# Snapdragon S1
# Snapdragon S1
# Snapdragon 400 Dual core
# Snapdragon S1
# Nvidia Tegra 3
# MediaTek
# Spreadtrum
# Snapdragon S4 Plus
# MediaTek
# MediaTek
# MediaTek
# MediaTek
# MediaTek
# Broadcom
# MediaTek
# Spreadtrum
# Spreadtrum
# MediaTek
# MediaTek
# MediaTek
# MediaTek
# MediaTek
# MediaTek
# Snapdragon 800 Quad core
# Broadcom
# MediaTek
# Snapdragon
# Snapdragon 800
# MediaTek
# MediaTek
# MediaTek Quad core
# Snapdragon 400
# MediaTek
# Snapdragon 200
# Snapdragon 400
# MediaTek
# MediaTek
# MediaTek
# MediaTek Quad core
# MediaTek
# MediaTek
# MediaTek
# MediaTek
# MediaTek
# Snapdragon 200
# MediaTek Tru-Octa Core
# MediaTek
# MediaTek Tru-Octa Core
# Snapdragon 200 Quad core
# HiSilicon Kirin Octa core
# MediaTek
# MediaTek Tru-Octa Core
# Snapdragon 400
# Intel Atom
# MediaTek
# MediaTek
# MediaTek
# MediaTek Tru-Octa Core
# MediaTek
# Snapdragon 200
# MediaTek Tru-Octa Core
# Snapdragon 801
# MediaTek
# MediaTek
# Snapdragon 615 Octa core
# MediaTek
# MediaTek
# Snapdragon 400
# Snapdragon 410
# MediaTek
# MediaTek
# Apple A8 Dual core
# Snapdragon 801
# Intel Atom
# MediaTek
# MediaTek Dual core
# MediaTek
# MediaTek Tru-Octa Core
# MediaTek
# MediaTek
# MediaTek Tru-Octa Core
# MediaTek Tru-Octa Core
# Intel Atom
# MediaTek Tru-Octa Core
# MediaTek
# HiSilicon Kirin Octa core
# MediaTek Quad core
# MediaTek
# MediaTek
# MediaTek Tru-Octa Core
# Snapdragon 410
# MediaTek Tru-Octa Core
# MediaTek
# Intel Atom
# MediaTek
# MediaTek
# MediaTek
# MediaTek Tru-Octa Core
# MediaTek Tru-Octa Core
# Snapdragon 410
# MediaTek Tru-Octa Core
# Spreadtrum Quad core
# MediaTek Quad core
# Snapdragon 615 Octa core
# Intel Atom Quad core
# MediaTek Quad core
# Spreadtrum Quad core
# Snapdragon 410
# MediaTek Tru-Octa Core
# Snapdragon 625 Tru-Octa Core
# Spreadtrum
# MediaTek Quad core
# MediaTek Tru-Octa Core
# Snapdragon 615 Octa core
# Spreadtrum
# MediaTek Dual core
# MediaTek Tru-Octa Core
# Snapdragon 615 Octa core
# MediaTek Quad core
# Snapdragon 615 Octa core
# Intel Atom
# MediaTek
# MediaTek
# Snapdragon 410
# MediaTek Quad core
# MediaTek Tru-Octa Core
# MediaTek Quad core
# Snapdragon 615 Octa core
# MediaTek
# Intel Atom
# Snapdragon 810 Octa core
# Snapdragon 616 Octa core
# MediaTek Quad core
# MediaTek
# Snapdragon 410
# MediaTek Tru-Octa Core
# MediaTek Tru-Octa Core
# Snapdragon 615 Octa core
# Spreadtrum
# MediaTek Quad core
# Spreadtrum Quad core
# Snapdragon 616 Octa core
# MediaTek Quad core
# Spreadtrum Dual core
# MediaTek Tru-Octa Core
# MediaTek Tru-Octa Core
# MediaTek
# MediaTek
# Spreadtrum Quad core
# Snapdragon 410 Quad core
# MediaTek Octa core
# Spreadtrum
# Snapdragon 820 Octa core
# Snapdragon 820 Octa core
# Snapdragon 410
# Spreadtrum
# Spreadtrum Quad core
# MediaTek
# MediaTek Quad core
# MediaTek Quad core
# MediaTek Dual core
# MediaTek Quad core
# Snapdragon 410 Quad core
# Snapdragon 615 Octa core
# Spreadtrum Quad core
# Spreadtrum Quad core
# Spreadtrum Quad core
# MediaTek Quad core
# Snapdragon 615 Octa core
# Snapdragon 808 Hexa Core
# Snapdragon 820 Quad core
# MediaTek Quad core
# Snapdragon 210 Quad core
# MediaTek Quad core
# MediaTek Quad core
# MediaTek Tru-Octa Core
# Snapdragon 650 Hexa Core
# MediaTek Quad core
# MediaTek Quad core
# Spreadtrum Quad core
# MediaTek Quad core
# MediaTek Quad core
# MediaTek Quad core
# Snapdragon 410 Quad core
# Snapdragon 410 Quad core
# Spreadtrum Quad core
# MediaTek Quad core
# Snapdragon 615 Octa core
# MediaTek
# Spreadtrum Quad core
# MediaTek Quad core
# Spreadtrum Quad core
# MediaTek Quad core
# Snapdragon 625 Tru-Octa Core
# Snapdragon 430 Tru-Octa Core
# MediaTek Quad core
# MediaTek
# Spreadtrum Quad core
# MediaTek Quad core
# MediaTek Quad core
# Snapdragon 820 Quad core
# MediaTek Quad core
# MediaTek Quad core
# MediaTek Tru-Octa Core
# MediaTek Quad core
# Snapdragon 821 Quad core
# MediaTek Quad core
# MediaTek Octa core
# MediaTek
# MediaTek Quad core
# Snapdragon 617 Octa core
# MediaTek Quad core
# MediaTek Tru-Octa Core
# Spreadtrum Quad core
# Spreadtrum Quad core
# MediaTek Octa core
# MediaTek Quad core
# Snapdragon 210 Quad core
# MediaTek Quad core
# Snapdragon 210 Quad core
# MediaTek Tru-Octa Core
# MediaTek Quad core
# MediaTek Quad core
# Snapdragon 617 Octa core
# MediaTek
# MediaTek Quad core
# MediaTek Quad core
# MediaTek Quad core
# MediaTek
# HiSilicon Kirin Octa core
# MediaTek Quad core
# MediaTek
# Snapdragon 410 Quad core
# Snapdragon 616 Octa core
# MediaTek Quad core
# Snapdragon 210 Quad core
# Snapdragon 652 Octa core
# Snapdragon 430 Tru-Octa Core
# Spreadtrum Quad core
# MediaTek
# Snapdragon 430 Octa core
# Spreadtrum Quad core
# Snapdragon 430 Tru-Octa Core
# Snapdragon 400 Quad core
# Spreadtrum Quad core
# MediaTek Quad core
# Snapdragon 430 Tru-Octa Core
# Spreadtrum Quad core
# MediaTek Quad core
# Snapdragon 430 Tru-Octa Core
# MediaTek Quad core
# Spreadtrum Quad core
# Snapdragon 653 Octa core
# Snapdragon 410 Quad core
# MediaTek Quad core
# MediaTek Quad core
# MediaTek Quad core
# Snapdragon 630 Tru-Octa Core
# Spreadtrum Quad core
# MediaTek Quad core
# Snapdragon 430 Tru-Octa Core
# MediaTek Quad core
# Spreadtrum Quad core
# MediaTek Quad core
# MediaTek Quad core
# MediaTek Quad core
# MediaTek Quad core
# MediaTek Quad core
# Snapdragon 435 Tru-Octa Core
# Spreadtrum Quad core
# MediaTek Quad core
# Spreadtrum Quad core
# MediaTek Quad core
# MediaTek Quad core
# MediaTek Quad core
# Snapdragon 210 Quad core
# MediaTek Quad core
# MediaTek Quad core
# Snapdragon 435 Tru-Octa Core
# MediaTek Octa core
# Spreadtrum Quad core
# MediaTek Quad core
# Spreadtrum Quad core
# MediaTek
# Snapdragon 435 Tru-Octa Core
# MediaTek Octa core
# MediaTek Quad core
# MediaTek Quad core
# Snapdragon 625 Tru-Octa Core
# MediaTek Octa core
# MediaTek Quad core
# MediaTek Quad core
# MediaTek Octa core
# MediaTek Quad core
# MediaTek Quad core
# Snapdragon 835 Octa core
# MediaTek Quad core
# MediaTek Quad core
# MediaTek Quad core
# MediaTek Quad core
# MediaTek Quad core
# MediaTek Quad core
# MediaTek Quad core
# MediaTek Quad core
# MediaTek Quad core
# Snapdragon 430 Tru-Octa Core
# Spreadtrum Quad core
# MediaTek Octa core
# MediaTek Quad core
# MediaTek Quad core
# Spreadtrum Quad core
# MediaTek
# MediaTek Quad core
# MediaTek Quad core
# MediaTek Quad core
# MediaTek Quad core
# MediaTek Quad core
# Snapdragon 660 Octa core
# MediaTek Quad core
# HiSilicon Kirin Octa core
# MediaTek Quad core
# MediaTek Quad core
# MediaTek Quad core
# Snapdragon 430 Tru-Octa Core
# Spreadtrum Quad core
# Spreadtrum Quad core
# Snapdragon 430 Tru-Octa Core
# MediaTek Quad core
# MediaTek Quad core
# Snapdragon 450 Tru-Octa Core
# MediaTek Quad core
# MediaTek Octa core
# MediaTek Quad core
# Snapdragon 210 Quad core
# MediaTek Quad core
# HiSilicon Kirin Octa core
# MediaTek Quad core
# Snapdragon 212 Quad core
# Snapdragon 630 Tru-Octa Core
# MediaTek Quad core
# Spreadtrum Quad core
# Spreadtrum Quad core
# MediaTek Quad core
# MediaTek Octa core
# MediaTek Quad core
# Snapdragon 435 Tru-Octa Core
# MediaTek Quad core
# MediaTek Quad core
# MediaTek Octa core
# MediaTek Octa core
# Snapdragon 845 Octa core
# MediaTek Quad core
# Spreadtrum Quad core
# MediaTek Quad core
# MediaTek Quad core
# MediaTek Quad core
# MediaTek Quad core
# MediaTek Quad core
# MediaTek Quad core
# MediaTek Quad core
# MediaTek Octa core
# Spreadtrum Quad core
# MediaTek Quad core
# Snapdragon 450 Tru-Octa Core
# Snapdragon 660 Octa core
# Spreadtrum Quad core
# MediaTek Quad core
# MediaTek Helio P22 Tru-Octa Core
# MediaTek Quad core
# MediaTek Quad core
# MediaTek Quad core
# MediaTek Octa core
# MediaTek Helio P22 Octa core
# Unisoc Quad core
# Snapdragon 430 Tru-Octa Core
# Snapdragon 210 Quad core
# MediaTek Helio A22 Quad core
# Snapdragon 625 Tru-Octa Core
# Intel Atom Quad core
# HiSilicon Kirin Octa core
# MediaTek Helio A22 Quad core
# Unisoc Quad core
# Snapdragon 632 Octa core
# Snapdragon 660 Octa core
# MediaTek Quad core
# MediaTek Quad core
# MediaTek Helio A22 Quad core
# MediaTek Quad core
# MediaTek Helio P22 Tru-Octa Core
# Unisoc Octa core
# MediaTek Quad core
# MediaTek Helio P22 Tru-Octa Core
# MediaTek Quad core
# Snapdragon 429 Quad core
# HiSilicon Kirin Octa core
# Snapdragon 632 Octa core
# MediaTek Quad core
# MediaTek Helio P22 Tru-Octa Core
# MediaTek Helio P22 Tru-Octa Core
# MediaTek Helio P22 Tru-Octa Core
# MediaTek Helio P70 Octa core
# MediaTek Helio P22 Tru-Octa Core
# MediaTek Helio A22 Quad core
# Snapdragon 855 Octa core
# Snapdragon 855 Octa core
# MediaTek Helio P35 Tru-Octa Core
# MediaTek Helio P22 Tru-Octa Core
# MediaTek Helio A22 Quad core
# MediaTek Helio P60 Octa core
# Unisoc Octa core
# MediaTek Helio A22 Quad core
# Unisoc Octa core
# MediaTek Helio P22 Tru-Octa Core
# MediaTek Helio P22 Tru-Octa Core
# MediaTek Helio P65 Octa core
# Snapdragon 712 Octa core
# Snapdragon 632 Octa core
# Unisoc Octa core
# Snapdragon 665 Octa core
# Unisoc Octa core
# MediaTek Helio P22 Tru-Octa Core
# MediaTek Helio P22 Tru-Octa Core
# Snapdragon 665 Octa core
# Unisoc Quad core
# MediaTek Helio P22 Tru-Octa Core
# MediaTek Helio P22 Tru-Octa Core
# MediaTek Helio A22 Quad core
# MediaTek Helio P22 Tru-Octa Core
# MediaTek Helio P22 Tru-Octa Core
# Samsung Exynos 9 Octa Octa core
# MediaTek Helio P22 Tru-Octa Core
# MediaTek Helio G85 Octa core
# Unisoc Tru-Octa Core
# MediaTek Helio A20 Quad core
# Unisoc Tru-Octa Core
# MediaTek Helio G95 Octa core
# MediaTek Helio A22 Quad core
# MediaTek Helio G80 Octa core
# MediaTek Helio P22 Tru-Octa Core
# Unisoc Octa core
# MediaTek Helio G80 Octa core
# MediaTek Helio P35 Tru-Octa Core
# MediaTek Helio P35 Tru-Octa Core
# Unisoc Tru-Octa Core
# Snapdragon 450 Tru-Octa Core
# MediaTek Helio G35 Tru-Octa Core
# MediaTek Helio G35 Tru-Octa Core
# MediaTek Quad core
# Unisoc Tru-Octa Core
# MediaTek Helio G80 Octa core
# MediaTek Helio A25 Octa core
# MediaTek Helio G35 Octa core
# MediaTek Helio G35 Tru-Octa Core
# Spreadtrum
# Apple A15 Bionic Hexa Core
# MediaTek Helio G90T Octa core
# Unisoc Quad core
# MediaTek Quad core
# MediaTek Quad core
# MediaTek Quad core
# Snapdragon 855 Plus Octa core
# MediaTek Helio A22 Quad core
# MediaTek Helio P35 Tru-Octa Core
# MediaTek Quad core
# MediaTek Helio A22 Quad core
# Spreadtrum Quad core
# Spreadtrum Quad core
# Spreadtrum Quad core
# Spreadtrum Quad core
# Spreadtrum Quad core
# Spreadtrum Quad core
# MediaTek Helio A22 Quad core
# MediaTek Quad core
# Snapdragon 210 Quad core
# MediaTek Quad core
# Snapdragon 425 Quad core
# Spreadtrum Quad core
# MediaTek Quad core
# MediaTek Octa core
# MediaTek Quad core
# Spreadtrum Quad core
# MediaTek Quad core
# Spreadtrum Quad core
# Spreadtrum Quad core
# MediaTek Tru-Octa Core
# MediaTek Quad core
# MediaTek Tru-Octa Core
# Snapdragon 425 Quad core
# MediaTek Quad core
# Spreadtrum Quad core
# Spreadtrum
# Spreadtrum
# Snapdragon 435 Tru-Octa Core
# MediaTek Quad core
# Spreadtrum Quad core
# MediaTek
# Spreadtrum Quad core
# MediaTek Quad core
# Snapdragon 630 Tru-Octa Core
# Spreadtrum Quad core
# Spreadtrum Quad core
# MediaTek
# MediaTek Quad core
# Spreadtrum Quad core
# MediaTek Quad core
# MediaTek Quad core
# MediaTek Tru-Octa Core
# Spreadtrum Quad core
# MediaTek Quad core
# Snapdragon 652 Octa core
# Snapdragon 652 Octa core
# Snapdragon 210 Quad core
# MediaTek Quad core
# Spreadtrum Quad core
# MediaTek Quad core
# Spreadtrum Quad core
# MediaTek Tru-Octa Core
# Spreadtrum Quad core
# MediaTek Quad core
# Spreadtrum Quad core
# Spreadtrum
# Snapdragon 617 Octa core
# MediaTek Quad core
# MediaTek Quad core
# MediaTek Quad core
# HiSilicon Kirin Tru-Octa Core
# MediaTek Quad core
# MediaTek Tru-Octa Core
# Spreadtrum Quad core
# Spreadtrum Quad core
# MediaTek Quad core
# Spreadtrum Quad core
# MediaTek Quad core
# MediaTek Quad core
# Spreadtrum Quad core
# Spreadtrum Quad core
# MediaTek Quad core
# Spreadtrum Quad core
# MediaTek Octa core
# MediaTek
# MediaTek Tru-Octa Core
# MediaTek
# MediaTek Quad core
# MediaTek Quad core
# MediaTek Quad core
# MediaTek Quad core
# Snapdragon 410
# Intel Atom
# MediaTek Quad core
# Spreadtrum Quad core
# MediaTek Tru-Octa Core
# MediaTek
# Spreadtrum
# MediaTek
# HiSilicon Kirin Octa core
# MediaTek
# MediaTek Tru-Octa Core
# MediaTek
# MediaTek
# Broadcom
# MediaTek
# MediaTek
# MediaTek
# MediaTek Tru-Octa Core
# MediaTek
# MediaTek Tru-Hexa Core
# MediaTek
# MediaTek Hexa Core
# Broadcom
# MediaTek
# MediaTek
# MediaTek
# MediaTek
# Snapdragon S4 Play Dual core
# Snapdragon S4 Play Dual core
# MediaTek
# MediaTek
# Broadcom
# Snapdragon
# MediaTek
# MediaTek
# Snapdragon S4 Play
# MediaTek
# Unisoc Octa core
# Unisoc Octa core
# Snapdragon 480 Octa core
# MediaTek Helio G35 Tru-Octa Core
# Unisoc Tru-Octa Core
# MediaTek Helio A22 Quad core
# Unisoc Octa core
# Spreadtrum Single core
# Unisoc Octa core
# Snapdragon S2
# Snapdragon S2
# MediaTek Helio A22 Quad core
# MediaTek Dimensity 6080 Octa core
# Unisoc Octa core
# MediaTek Helio G88 Octa core
# MediaTek Dimensity 6300 Octa core
# Snapdragon 7s Gen 3 Octa core

# %%
df.drop(columns = ['mobile_name','battery_and_charging_speed','operating_system','5G|NFC|Fingerprint','ram_and_storage','display','display','cpu'],inplace = True)

# %%
final_df=df[['brand', 'model', 'release_date', 'price', 'avg_rating','total_ratings', 'rear_camera', 'front_camera', 'display_size(inch)','display_type','refresh_rate(Hz)','ram(gb)', 'storage(gb)','battery_size(mAh)', 'cpu_brand', 'cpu_model','charging_speed(W)', 'os_type', 'os_version', '5g', 'nfc','fingerprint', 'expert_view']]

# %%
final_df.to_csv('mysmartprice_mobile_dataset_cleaned.csv')
